# %% [markdown]
# # Download and run zonal stats on WOfS water statistics
#
# https://docs.digitalearthafrica.org/en/latest/data_specs/Landsat_WOfS_specs.html
#
# For the WOfS daily data, the data need to be downloaded and then processed.

# %%
import sys, os, importlib, json, multiprocessing
import rasterio, boto3

import pandas as pd
import geopandas as gpd
import GOSTRocks.rasterMisc as rMisc

from tqdm import tqdm
from osgeo import gdal
from shapely.geometry import shape
from botocore import UNSIGNED
from botocore.config import Config
from GOSTRocks.misc import tPrint

bucket = 'deafrica-services'
prefix = 'wofs_ls' # 'wofs_ls_summary_annual'
region = 'af-south-1'
s3client = boto3.client('s3', region_name='af-south-1', config=Config(signature_version=UNSIGNED))

# %%
in_folder = "/home/wb411133/projects/WOFS_Walker"
pt_files = [os.path.join(in_folder, x) for x in os.listdir(in_folder) if x.endswith(".shp")]

in_extents = gpd.read_file("wofs_ls_summary_alltime-regions-deafrica-data.geojson")
in_extents['COL'] = in_extents['region_code'].apply(lambda x: int(x.split("_")[0]) + 84) # 181 These additions transform numbers for downloads
in_extents['ROW'] = in_extents['region_code'].apply(lambda x: int(x.split("_")[1]) + 96) #
in_extents['COL_ROW'] = in_extents.apply(lambda x: f"{x['COL']}_{x['ROW']}", axis=1)
extents_index = in_extents.sindex
                                         
landsat_extents = gpd.read_file("/home/public/Data/GLOBAL/WRS2_descending.shp")
landsat_index = landsat_extents.sindex

# %%
final_folder = os.path.join(in_folder, "WOFS_Daily_summaries")
if not os.path.exists(final_folder):
    os.makedirs(final_folder)

# %%
wofs_tiles = pd.read_csv("WOFS_AWS_SUMMARY.csv", index_col=0)
wofs_tiles['MONTH'] = wofs_tiles['Key'].apply(lambda x: x.split("/")[-3])
wofs_tiles['DAY'] = wofs_tiles['Key'].apply(lambda x: x.split("/")[-2])
wofs_tiles.head()
# Out:
# /home/wb411133/.conda/envs/ee/lib/python3.9/site-packages/numpy/lib/arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                                                  Key  \
# 0  wofs_ls/1-0-0/148/072/2005/11/21/wofs_ls_14807...
# 1  wofs_ls/1-0-0/148/072/2005/12/23/wofs_ls_14807...
# 2  wofs_ls/1-0-0/148/072/2006/01/24/wofs_ls_14807...
# 3  wofs_ls/1-0-0/148/072/2006/02/25/wofs_ls_14807...
# 4  wofs_ls/1-0-0/148/072/2006/04/30/wofs_ls_14807...
#
#                 LastModified                                  ETag      Size  \
# 0  2021-09-01 04:58:11+00:00    "865518daa97eb5abada45389ca8275b0"  3.961378
# 1  2021-09-01 04:06:08+00:00    "ada110dbc2125e9f887503c1d1eb6099"  3.956423
# 2  2021-09-01 04:09:59+00:00    "8baba74aab96bd79fdf4e1e598f5eba0"  4.412727
# 3  2021-09-01 03:58:38+00:00  "d960813048736658c36542711939e9f7-2"  8.448545
# 4  2021-09-01 04:10:04+00:00    "58b52ddc11ff59c1b56d7d20334d0052"  3.539613
#
#   StorageClass  COL  ROW COL_ROW   TYPE  YEAR MONTH DAY
# 0     STANDARD  148   72  148_72  water  2005    11  21
# 1     STANDARD  148   72  148_72  water  2005    12  23
# 2     STANDARD  148   72  148_72  water  2006    01  24
# 3     STANDARD  148   72  148_72  water  2006    02  25
# 4     STANDARD  148   72  148_72  water  2006    04  30

# %% [markdown]
# # Download and create VRT files for WOFS data

# %%
sel_year = 2011
out_folder = os.path.join(in_folder, "IMAGES", str(sel_year))
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
    
for pt_file in pt_files:
    # Read in the current points file
    pt_name = os.path.basename(pt_file)[:-4]
    final_year = os.path.join(final_folder, f'{pt_name}_{sel_year}.csv')
    if not os.path.exists(final_year):
        curPt = gpd.read_file(pt_file)
        pt_geom = [(x.x, x.y) for x in curPt['geometry']]
        pt_final = curPt.copy()
        # Find intersecting Landsat tiles
        potential_tiles = landsat_extents.iloc[list(landsat_index.intersection(curPt.total_bounds))].sort_values(['PATH','ROW'])
        tPrint(f"Downloading imagery for {pt_name} in {sel_year}")
        for idx, row in potential_tiles.iterrows():
            # For each Landsat tile, identify the WOFS tiles
            sel_wofs = wofs_tiles.loc[(wofs_tiles['ROW'] == row['ROW']) & 
                                      (wofs_tiles['COL'] == row['PATH']) & 
                                      (wofs_tiles['TYPE'] == 'water') &
                                      (wofs_tiles['YEAR'] == sel_year)]
            if sel_wofs.shape[0] > 0:
                # Download each image in the selected tile, organized by day and month
                for sel_idx, sel_row in sel_wofs.iterrows():
                    image_folder = os.path.join(out_folder, sel_row['MONTH'], sel_row['DAY'])
                    if not os.path.exists(image_folder):
                        os.makedirs(image_folder)
                    out_file = os.path.join(image_folder, os.path.basename(sel_row['Key']))
                    if not os.path.exists(out_file):
                        s3client.download_file(bucket, sel_row['Key'], out_file)                        
        tPrint('Download Complete')
        # Create VRT file for each YEAR_MONTH_DAY 
        all_dirs = []
        all_vrts = []
        for root, dirs, files in os.walk(out_folder):
            if os.path.basename(root) != str(sel_year):
                for d in dirs:
                    all_dirs.append(os.path.join(root, d))
            for c_dir in all_dirs:
                out_vrt = os.path.join(os.path.dirname(c_dir), f'WOFS_VRT_{"_".join(c_dir.split("/")[-3:])}.vrt')
                vrt_files = [os.path.join(c_dir, x) for x in os.listdir(c_dir)]                       
                vrt_options = gdal.BuildVRTOptions(resampleAlg='cubic', addAlpha=True)
                my_vrt = gdal.BuildVRT(out_vrt, vrt_files, options=vrt_options)
                my_vrt = None
                all_vrts.append(out_vrt)
        # Run zonal stats on created VRT files
        all_vrts.sort()
        for vrt in all_vrts:
            if not os.path.basename(vrt)[:-4] in pt_final.columns:
                curR = rasterio.open(vrt)
                pt_res = [x[0] for x in curR.sample(pt_geom)]
                pt_final[os.path.basename(vrt)[:-4]] = pt_res
                # tPrint(os.path.basename(vrt)[:-4])

        pd.DataFrame(pt_final.drop(['geometry'], axis=1)).to_csv(final_year)

# %%
xx = pd.DataFrame(pt_final.drop(['geometry'], axis=1))
xx.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-77900167aecf> in <module>
# ----> 1 xx = pd.DataFrame(pt_final.drop(['geometry'], axis=1))
#       2 xx.head()
#
# NameError: name 'pt_final' is not defined

# %%
final_year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-69862d99e327> in <module>
# ----> 1 final_year
#
# NameError: name 'final_year' is not defined

# %% [markdown]
# # Run grid-base zonal stats

# %%
unq_vals = [128, 130, 160]

grid_folder = "/home/wb411133/projects/WOFS_Walker/GRIDS"
grids = [os.path.join(grid_folder, x) for x in os.listdir(grid_folder) if x.endswith(".shp")]

vrt_folder = "/home/wb411133/projects/WOFS_Walker/IMAGES/2011"
vrts = []
for root, dirs, files in os.walk(vrt_folder):
    for f in files:
        if f.endswith(".vrt"):
            vrts.append(os.path.join(root, f))

# %%
# Group VRTs into months
vrt_months = {}
for vrt in vrts:
    cur_month = vrt.split("_")[-2]
    try:
        vrt_months[cur_month].append(vrt)
    except:
        vrt_months[cur_month] = [vrt]

# %%
vrt_months
# Out:
# {'01': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_31.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_09.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_26.vrt'],
#  '02': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/02/WOFS_VRT_2011_02_09.vrt'],
#  '03': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_31.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/03/WOFS_VRT_2011_03_13.vrt'],
#  '04': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_09.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/04/WOFS_VRT_2011_04_12.vrt'],
#  '06': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/06/WOFS_VRT_2011_06_04.vrt'],
#  '07': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_09.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/07/WOFS_VRT_2011_07_14.vrt'],
#  '08': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_09.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_31.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/08/WOFS_VRT_2011_08_15.vrt'],
#  '09': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/09/WOFS_VRT_2011_09_05.vrt'],
#  '10': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_31.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/10/WOFS_VRT_2011_10_22.vrt'],
#  '11': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_09.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/11/WOFS_VRT_2011_11_23.vrt'],
#  '12': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_31.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_09.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/12/WOFS_VRT_2011_12_30.vrt'],
#  '05': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_31.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/05/WOFS_VRT_2011_05_09.vrt']}

# %% [markdown]
# ### Run straight up

# %%
for cur_grid in grids:
    grid_folder = os.path.join(final_folder, os.path.basename(cur_grid).replace(".shp", ""))
    if not os.path.exists(grid_folder):
        os.makedirs(grid_folder)
    for month, vrts in vrt_months.items():
        try:
            del final
        except:
            pass
        out_file = os.path.join(grid_folder, os.path.basename(cur_grid).replace(".shp", f"_{month}.csv"))
        if not os.path.exists(out_file):
            curD = gpd.read_file(cur_grid)
            pbar = tqdm(vrts)
            pbar.set_description(f'Processing {os.path.basename(cur_grid).replace(".shp", "")} {month}')

            for cur_vrt in pbar:
                curR = rasterio.open(cur_vrt)
                if curD.crs != curR.crs:
                    curD = curD.to_crs(curR.crs)
                date = "_".join(cur_vrt.split("_")[-3:]).replace(".vrt", "")

                res = rMisc.zonalStats(curD, curR, rastType='C', unqVals=unq_vals)
                res = pd.DataFrame(res, columns=[f'{date}_{x}' for x in unq_vals])

                try:
                    final = final.join(res)                
                except:
                    final = res            
            final['GRID_ID'] = curD['GRID_ID']
            final.to_csv(out_file)
# Out:
# Processing grid_BFA01_ply 01:   0%|          | 0/29 [01:12<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-96ed13089470> in <module>
#      20                 date = "_".join(cur_vrt.split("_")[-3:]).replace(".vrt", "")
#      21
# ---> 22                 res = rMisc.zonalStats(curD, curR, rastType='C', unqVals=unq_vals)
#      23                 res = pd.DataFrame(res, columns=[f'{date}_{x}' for x in unq_vals])
#      24
#
# ~/.conda/envs/ee/lib/python3.9/site-packages/GOSTRocks/rasterMisc.py in zonalStats(inShp, inRaster, bandNum, mask_A, reProj, minVal, maxVal, verbose, rastType, unqVals, weighted, allTouched)
#     293     b = curRaster.bounds
#     294     rBox = box(b[0], b[1], b[2], b[3])
# --> 295     for idx, row in inVector.iterrows():
#     296         geometry = row['geometry']
#     297         fCount = fCount + 1
#
# ~/.conda/envs/ee/lib/python3.9/site-packages/pandas/core/frame.py in iterrows(self)
#    1069         klass = self._constructor_sliced
#    1070         for k, v in zip(self.index, self.values):
# -> 1071             s = klass(v, index=columns, name=k)
#    1072             yield k, s
#    1073
#
# ~/.conda/envs/ee/lib/python3.9/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     362                     data = data.copy()
#     363             else:
# --> 364                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     365
#     366                 data = SingleBlockManager.from_array(data, index)
#
# ~/.conda/envs/ee/lib/python3.9/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     459         else:
#     460             # we will try to copy be-definition here
# --> 461             subarr = _try_cast(data, dtype, copy, raise_cast_failure)
#     462
#     463     elif isinstance(data, ABCExtensionArray):
#
# ~/.conda/envs/ee/lib/python3.9/site-packages/pandas/core/construction.py in _try_cast(arr, dtype, copy, raise_cast_failure)
#     569     # perf shortcut as this is the most common case
#     570     if isinstance(arr, np.ndarray):
# --> 571         if maybe_castable(arr) and not copy and dtype is None:
#     572             return arr
#     573
#
# ~/.conda/envs/ee/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in maybe_castable(arr)
#    1268         return is_timedelta64_ns_dtype(arr.dtype)
#    1269
# -> 1270     return arr.dtype.name not in POSSIBLY_CAST_DTYPES
#    1271
#    1272
#
# ~/.conda/envs/ee/lib/python3.9/site-packages/numpy/core/_dtype.py in _name_get(dtype)
#     319
#     320
# --> 321 def _name_get(dtype):
#     322     # provides dtype.name.__get__, documented as returning a "bit name"
#     323
#
# KeyboardInterrupt:

# %% [markdown]
# ### Multi-processing

# %%
unq_vals = [128, 130, 160]
def run_zonal(x_cur_grid, x_vrts, x_out_file):
    curD = gpd.read_file(x_cur_grid)
    #pbar = tqdm(x_vrts)
    #pbar.set_description(f'Processing {os.path.basename(x_out_file).replace(".csv", "")}')
    for cur_vrt in vrts:
        curR = rasterio.open(cur_vrt)
        if curD.crs != curR.crs:
            curD = curD.to_crs(curR.crs)
        date = "_".join(cur_vrt.split("_")[-3:]).replace(".vrt", "")
        
        res = rMisc.zonalStats(curD, curR, rastType='C', unqVals=unq_vals)
        res = pd.DataFrame(res, columns=[f'{date}_{x}' for x in unq_vals])

        try:
            final = final.join(res)                
        except:
            final = res
        # tPrint(cur_vrt)
    final['GRID_ID'] = curD['GRID_ID']
    final.to_csv(x_out_file)
    tPrint(f'Completed {os.path.basename(x_out_file).replace(".csv", "")}')

# %%
try:
    del final
except:
    pass

mp_args = []        
for cur_grid in grids:
    for month, vrts in vrt_months.items():
        out_file = os.path.join(final_folder, os.path.basename(cur_grid).replace(".shp", f"_{month}2011.csv"))
        if not os.path.exists(out_file):
            mp_args.append([cur_grid, vrts, out_file])

print (len(mp_args))
# Out:
# 1

# %%
mp_args
# Out:
# [['/home/wb411133/projects/WOFS_Walker/GRIDS/grid_BFA01_ply.shp',
#   ['/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_07.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_23.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_15.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_31.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_14.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_22.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_30.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_05.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_21.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_12.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_20.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_28.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_04.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_03.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_11.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_19.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_02.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_18.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_10.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_09.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_25.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_08.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_24.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_06.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_13.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_01.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_29.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_27.vrt',
#    '/home/wb411133/projects/WOFS_Walker/IMAGES/2011/01/WOFS_VRT_2011_01_26.vrt'],
#   '/home/wb411133/projects/WOFS_Walker/WOFS_Daily_summaries/grid_BFA01_ply_012011.csv']]

# %%
nCores = min([60, len(mp_args)])
with multiprocessing.Pool(nCores) as pool:
    pool.starmap(run_zonal, mp_args)

# %% [markdown]
# # DEBUGGING
