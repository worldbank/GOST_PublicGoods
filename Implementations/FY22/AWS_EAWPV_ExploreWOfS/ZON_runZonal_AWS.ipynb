# %% [markdown]
# # Download and run zonal stats on WOfS water statistics
#
# https://docs.digitalearthafrica.org/en/latest/data_specs/Landsat_WOfS_specs.html
#
# For the WOfS daily data, the data need to be downloaded and then processed.

# %%
import sys, os, importlib, json, multiprocessing
import rasterio, boto3

import pandas as pd
import geopandas as gpd
import numpy as np
import GOSTRocks.rasterMisc as rMisc

from tqdm import tqdm
from osgeo import gdal
from shapely.geometry import shape, Polygon, box
from botocore import UNSIGNED
from botocore.config import Config
from GOSTRocks.misc import tPrint

bucket = 'deafrica-services'
prefix = 'wofs_ls' # 'wofs_ls_summary_annual'
region = 'af-south-1'
s3client = boto3.client('s3', region_name='af-south-1', config=Config(signature_version=UNSIGNED))

# %%
in_folder = "/home/wb411133/projects/WOFS_Walker"
grid_folder = os.path.join(in_folder, "GRIDS")
pt_files = [os.path.join(grid_folder, x) for x in os.listdir(grid_folder) if x.endswith(".shp")]

in_extents = gpd.read_file("wofs_ls_summary_alltime-regions-deafrica-data.geojson")
in_extents['COL'] = in_extents['region_code'].apply(lambda x: int(x.split("_")[0]) + 84) # 181 These additions transform numbers for downloads
in_extents['ROW'] = in_extents['region_code'].apply(lambda x: int(x.split("_")[1]) + 96) #
in_extents['COL_ROW'] = in_extents.apply(lambda x: f"{x['COL']}_{x['ROW']}", axis=1)
extents_index = in_extents.sindex
                                         
landsat_extents = gpd.read_file("/home/public/Data/GLOBAL/WRS2_descending.shp")
landsat_index = landsat_extents.sindex

# %%
final_folder = os.path.join(in_folder, "WOFS_Daily_summaries")
if not os.path.exists(final_folder):
    os.makedirs(final_folder)

# %%
wofs_tiles = pd.read_csv(os.path.join(in_folder,"WOFS_AWS_SUMMARY.csv"), index_col=0)
wofs_tiles['MONTH'] = wofs_tiles['Key'].apply(lambda x: x.split("/")[-3])
wofs_tiles['DAY'] = wofs_tiles['Key'].apply(lambda x: x.split("/")[-2])
wofs_tiles.head()
# Out:
# /home/wb411133/.conda/envs/ee/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /home/wb411133/.conda/envs/ee/lib/python3.9/site-packages/numpy/lib/arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                                                  Key  \
# 0  wofs_ls/1-0-0/148/072/2005/11/21/wofs_ls_14807...
# 1  wofs_ls/1-0-0/148/072/2005/12/23/wofs_ls_14807...
# 2  wofs_ls/1-0-0/148/072/2006/01/24/wofs_ls_14807...
# 3  wofs_ls/1-0-0/148/072/2006/02/25/wofs_ls_14807...
# 4  wofs_ls/1-0-0/148/072/2006/04/30/wofs_ls_14807...
#
#                 LastModified                                  ETag      Size  \
# 0  2021-09-01 04:58:11+00:00    "865518daa97eb5abada45389ca8275b0"  3.961378
# 1  2021-09-01 04:06:08+00:00    "ada110dbc2125e9f887503c1d1eb6099"  3.956423
# 2  2021-09-01 04:09:59+00:00    "8baba74aab96bd79fdf4e1e598f5eba0"  4.412727
# 3  2021-09-01 03:58:38+00:00  "d960813048736658c36542711939e9f7-2"  8.448545
# 4  2021-09-01 04:10:04+00:00    "58b52ddc11ff59c1b56d7d20334d0052"  3.539613
#
#   StorageClass  COL ROW  COL_ROW   TYPE  YEAR MONTH DAY
# 0     STANDARD  148  72  148_072  water  2005    11  21
# 1     STANDARD  148  72  148_072  water  2005    12  23
# 2     STANDARD  148  72  148_072  water  2006    01  24
# 3     STANDARD  148  72  148_072  water  2006    02  25
# 4     STANDARD  148  72  148_072  water  2006    04  30

# %% [markdown]
# # Download and create VRT files for WOFS data

# %%
sel_year = 2017

# %%
out_folder = os.path.join(in_folder, "IMAGES", str(sel_year))
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
    
for pt_file in pt_files:
    # Read in the current points file
    pt_name = os.path.basename(pt_file)[:-4]
    final_year = os.path.join(final_folder, f'{pt_name}_{sel_year}.csv')
    if not os.path.exists(final_year):
        curPt = gpd.read_file(pt_file)
        # Find intersecting Landsat tiles
        potential_tiles = landsat_extents.iloc[list(landsat_index.intersection(curPt.total_bounds))].sort_values(['PATH','ROW'])
        tPrint(f"Downloading imagery for {pt_name} in {sel_year}")
        for idx, row in potential_tiles.iterrows():
            # For each Landsat tile, identify the WOFS tiles
            sel_wofs = wofs_tiles.loc[(wofs_tiles['ROW'] == row['ROW']) & 
                                      (wofs_tiles['COL'] == row['PATH']) & 
                                      (wofs_tiles['TYPE'] == 'water') &
                                      (wofs_tiles['YEAR'] == sel_year)]
            if sel_wofs.shape[0] > 0:
                # Download each image in the selected tile, organized by day and month
                for sel_idx, sel_row in sel_wofs.iterrows():
                    image_folder = os.path.join(out_folder, sel_row['MONTH'], sel_row['DAY'])
                    if not os.path.exists(image_folder):
                        os.makedirs(image_folder)
                    out_file = os.path.join(image_folder, os.path.basename(sel_row['Key']))
                    if not os.path.exists(out_file):
                        s3client.download_file(bucket, sel_row['Key'], out_file)                        
        tPrint('Download Complete')
        # Create VRT file for each YEAR_MONTH_DAY 
        all_dirs = []
        all_vrts = []
        for root, dirs, files in os.walk(out_folder):
            if os.path.basename(root) != str(sel_year):
                for d in dirs:
                    all_dirs.append(os.path.join(root, d))
            for c_dir in all_dirs:
                out_vrt = os.path.join(os.path.dirname(c_dir), f'WOFS_VRT_{"_".join(c_dir.split("/")[-3:])}.vrt')
                vrt_files = [os.path.join(c_dir, x) for x in os.listdir(c_dir)]                       
                vrt_options = gdal.BuildVRTOptions(resampleAlg='cubic', addAlpha=True)
                my_vrt = gdal.BuildVRT(out_vrt, vrt_files, options=vrt_options)
                my_vrt = None
                all_vrts.append(out_vrt)
# Out:
# 10:02:17	Downloading imagery for grid_MLI05_ply in 2017
# 10:13:02	Download Complete
# 10:16:29	Downloading imagery for grid_MLI06_ply in 2017
# 10:23:56	Download Complete
# 10:29:47	Downloading imagery for grid_MLI07_ply in 2017
# 10:36:35	Download Complete
# 10:44:49	Downloading imagery for grid_BFA01_ply in 2017
# 10:54:00	Download Complete
# 11:04:47	Downloading imagery for grid_BFA02_ply in 2017
# 11:09:57	Download Complete
# 11:22:21	Downloading imagery for grid_MLI01_ply in 2017
# 11:29:58	Download Complete
# 11:44:22	Downloading imagery for grid_MLI02_ply in 2017
# 11:45:49	Download Complete
# 12:00:41	Downloading imagery for grid_MLI03_ply in 2017
# 12:00:46	Download Complete
# 12:16:12	Downloading imagery for grid_MLI04_ply in 2017
# 12:28:35	Download Complete

# %% [markdown]
# # Run grid-base zonal stats

# %%
unq_vals = [128, 130, 160]

grid_folder = "/home/wb411133/projects/WOFS_Walker/GRIDS"
grids = [os.path.join(grid_folder, x) for x in os.listdir(grid_folder) if x.endswith(".shp")]

vrt_folder = f"/home/wb411133/projects/WOFS_Walker/IMAGES/{sel_year}"
vrts = []
for root, dirs, files in os.walk(vrt_folder):
    for f in files:
        if f.endswith(".vrt"):
            vrts.append(os.path.join(root, f))

# %%
# Group VRTs into months
vrt_months = {}
for vrt in vrts:
    cur_month = vrt.split("_")[-2]
    try:
        vrt_months[cur_month].append(vrt)
    except:
        vrt_months[cur_month] = [vrt]

# %%
vrt_months
# Out:
# {'01': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_09.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_31.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/01/WOFS_VRT_2017_01_28.vrt'],
#  '02': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_09.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/02/WOFS_VRT_2017_02_21.vrt'],
#  '03': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_31.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_09.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/03/WOFS_VRT_2017_03_15.vrt'],
#  '04': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_09.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/04/WOFS_VRT_2017_04_16.vrt'],
#  '05': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_31.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/05/WOFS_VRT_2017_05_09.vrt'],
#  '06': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_09.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/06/WOFS_VRT_2017_06_10.vrt'],
#  '07': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_09.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_31.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/07/WOFS_VRT_2017_07_30.vrt'],
#  '08': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_31.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_09.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/08/WOFS_VRT_2017_08_06.vrt'],
#  '09': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_09.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/09/WOFS_VRT_2017_09_16.vrt'],
#  '10': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_09.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_31.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/10/WOFS_VRT_2017_10_27.vrt'],
#  '11': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_09.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_30.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/11/WOFS_VRT_2017_11_01.vrt'],
#  '12': ['/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_05.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_13.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_21.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_29.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_04.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_12.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_20.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_28.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_03.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_11.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_19.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_27.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_02.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_10.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_18.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_26.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_01.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_09.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_17.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_25.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_08.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_16.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_24.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_07.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_15.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_23.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_31.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_06.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_14.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_22.vrt',
#   '/home/wb411133/projects/WOFS_Walker/IMAGES/2017/12/WOFS_VRT_2017_12_30.vrt']}

# %% [markdown]
# ### Multi-processing

# %%
unq_vals = [128, 130, 160]
def run_zonal(x_cur_grid, x_vrts, x_out_file):
    curD = gpd.read_file(x_cur_grid)
    #pbar = tqdm(x_vrts)
    #pbar.set_description(f'Processing {os.path.basename(x_out_file).replace(".csv", "")}')
    for cur_vrt in vrts:
        curR = rasterio.open(cur_vrt)
        if curD.crs != curR.crs:
            curD = curD.to_crs(curR.crs)
        date = "_".join(cur_vrt.split("_")[-3:]).replace(".vrt", "")
        
        res = rMisc.zonalStats(curD, curR, rastType='C', unqVals=unq_vals)
        res = pd.DataFrame(res, columns=[f'{date}_{x}' for x in unq_vals])

        try:
            final = final.join(res)                
        except:
            final = res        
    final['GRID_ID'] = curD['GRID_ID']
    final.to_csv(x_out_file)
    tPrint(f'Completed {os.path.basename(x_out_file).replace(".csv", "")}')

# %%
try:
    del final
except:
    pass

mp_args = []        
for cur_grid in grids:
    for month, vrts in vrt_months.items():
        out_file = os.path.join(final_folder, os.path.basename(cur_grid).replace(".shp", f"_{month}_{sel_year}.csv"))        
        if not os.path.exists(out_file):
            mp_args.append([cur_grid, vrts, out_file])

print (len(mp_args))
# Out:
# 108

# %%
nCores = min([60, len(mp_args)])
with multiprocessing.Pool(nCores) as pool:
    pool.starmap(run_zonal, mp_args)
# Out:
# 16:10:22	Completed grid_BFA01_ply_07_2017
# 16:17:38	Completed grid_BFA01_ply_11_2017
# 16:19:03	Completed grid_BFA01_ply_08_2017
# 16:20:34	Completed grid_BFA01_ply_12_2017
# 16:21:04	Completed grid_BFA01_ply_10_2017
# 16:21:30	Completed grid_BFA01_ply_09_2017
# 16:22:16	Completed grid_BFA01_ply_02_2017
# 16:23:06	Completed grid_BFA01_ply_06_2017
# 16:23:44	Completed grid_BFA01_ply_04_2017
# 16:24:01	Completed grid_BFA01_ply_05_2017
# 16:24:29	Completed grid_BFA01_ply_03_2017
# 16:25:44	Completed grid_BFA01_ply_01_2017
# 17:57:03	Completed grid_MLI01_ply_01_2017
# 18:10:38	Completed grid_MLI01_ply_02_2017
# 18:11:51	Completed grid_MLI01_ply_04_2017
# 18:12:55	Completed grid_MLI01_ply_05_2017
# 18:12:58	Completed grid_MLI01_ply_03_2017
# 18:13:23	Completed grid_MLI01_ply_06_2017
# 18:17:04	Completed grid_MLI01_ply_08_2017
# 18:19:02	Completed grid_MLI01_ply_09_2017
# 18:19:49	Completed grid_MLI01_ply_07_2017
# 18:20:08	Completed grid_MLI01_ply_11_2017
# 18:22:52	Completed grid_MLI01_ply_12_2017
# 18:24:37	Completed grid_BFA02_ply_11_2017
# 18:24:41	Completed grid_BFA02_ply_12_2017
# 18:24:50	Completed grid_BFA02_ply_07_2017
# 18:24:50	Completed grid_BFA02_ply_09_2017
# 18:24:52	Completed grid_BFA02_ply_10_2017
# 18:25:42	Completed grid_BFA02_ply_05_2017
# 18:26:09	Completed grid_BFA02_ply_06_2017
# 18:27:30	Completed grid_BFA02_ply_03_2017
# 18:27:36	Completed grid_MLI01_ply_10_2017
# 18:27:50	Completed grid_BFA02_ply_02_2017
# 18:27:55	Completed grid_BFA02_ply_01_2017
# 18:29:02	Completed grid_BFA02_ply_08_2017
# 18:34:58	Completed grid_BFA02_ply_04_2017
# 18:48:47	Completed grid_MLI06_ply_03_2017
# 18:50:15	Completed grid_MLI02_ply_01_2017
# 18:59:52	Completed grid_MLI06_ply_12_2017
# 19:01:11	Completed grid_MLI06_ply_07_2017
# 19:01:42	Completed grid_MLI06_ply_11_2017
# 19:01:48	Completed grid_MLI06_ply_09_2017
# 19:03:25	Completed grid_MLI06_ply_08_2017
# 19:04:38	Completed grid_MLI06_ply_10_2017
# 19:06:51	Completed grid_MLI02_ply_02_2017
# 19:07:49	Completed grid_MLI02_ply_03_2017
# 19:08:14	Completed grid_MLI06_ply_06_2017
# 19:09:09	Completed grid_MLI02_ply_05_2017
# 19:09:31	Completed grid_MLI02_ply_04_2017
# 19:09:50	Completed grid_MLI02_ply_06_2017
# 19:09:57	Completed grid_MLI06_ply_05_2017
# 19:10:54	Completed grid_MLI06_ply_04_2017
# 19:13:47	Completed grid_MLI02_ply_07_2017
# 19:14:14	Completed grid_MLI06_ply_02_2017
# 19:15:33	Completed grid_MLI02_ply_08_2017
# 19:15:52	Completed grid_MLI06_ply_01_2017
# 19:16:29	Completed grid_MLI02_ply_09_2017
# 19:16:41	Completed grid_MLI02_ply_10_2017
# 19:17:23	Completed grid_MLI02_ply_12_2017
# 19:19:14	Completed grid_MLI02_ply_11_2017
# 19:42:02	Completed grid_MLI07_ply_11_2017
# 19:42:43	Completed grid_MLI07_ply_12_2017
# 19:45:31	Completed grid_MLI07_ply_10_2017
# 19:46:51	Completed grid_MLI07_ply_08_2017
# 19:49:41	Completed grid_MLI07_ply_05_2017
# 19:49:58	Completed grid_MLI07_ply_06_2017
# 19:50:55	Completed grid_MLI05_ply_05_2017
# 19:51:33	Completed grid_MLI05_ply_11_2017
# 19:51:55	Completed grid_MLI07_ply_02_2017
# 19:53:11	Completed grid_MLI07_ply_03_2017
# 19:59:57	Completed grid_MLI05_ply_12_2017
# 20:04:53	Completed grid_MLI05_ply_09_2017
# 20:08:30	Completed grid_MLI05_ply_08_2017
# 20:09:11	Completed grid_MLI05_ply_10_2017
# 20:10:41	Completed grid_MLI07_ply_09_2017
# 20:11:57	Completed grid_MLI05_ply_07_2017
# 20:12:38	Completed grid_MLI07_ply_07_2017
# 20:13:20	Completed grid_MLI07_ply_04_2017
# 20:15:32	Completed grid_MLI05_ply_06_2017
# 20:17:55	Completed grid_MLI05_ply_02_2017
# 20:18:39	Completed grid_MLI07_ply_01_2017
# 20:19:50	Completed grid_MLI05_ply_04_2017
# 20:22:29	Completed grid_MLI05_ply_03_2017
# 20:29:17	Completed grid_MLI05_ply_01_2017
# 21:39:50	Completed grid_MLI03_ply_11_2017
# 21:40:18	Completed grid_MLI03_ply_01_2017
# 21:40:35	Completed grid_MLI03_ply_04_2017
# 21:40:45	Completed grid_MLI03_ply_03_2017
# 21:40:45	Completed grid_MLI03_ply_02_2017
# 21:41:38	Completed grid_MLI03_ply_05_2017
# 21:42:45	Completed grid_MLI03_ply_06_2017
# 21:42:54	Completed grid_MLI03_ply_07_2017
# 21:44:10	Completed grid_MLI03_ply_08_2017
# 21:44:32	Completed grid_MLI03_ply_10_2017
# 21:44:38	Completed grid_MLI03_ply_09_2017
# 21:48:28	Completed grid_MLI03_ply_12_2017
# 01:27:15	Completed grid_MLI04_ply_01_2017
# 01:31:39	Completed grid_MLI04_ply_02_2017
# 01:42:41	Completed grid_MLI04_ply_05_2017
# 01:44:14	Completed grid_MLI04_ply_04_2017
# 01:44:40	Completed grid_MLI04_ply_07_2017
# 01:45:34	Completed grid_MLI04_ply_10_2017
# 01:45:52	Completed grid_MLI04_ply_03_2017
# 01:46:21	Completed grid_MLI04_ply_08_2017
# 01:47:01	Completed grid_MLI04_ply_11_2017
# 01:48:03	Completed grid_MLI04_ply_09_2017
# 01:48:50	Completed grid_MLI04_ply_06_2017
# 01:52:05	Completed grid_MLI04_ply_12_2017

# %%
print("FUBAR")

# %% [markdown]
# ### Run individually

# %%
for cur_grid in grids:
    grid_folder = os.path.join(final_folder, os.path.basename(cur_grid).replace(".shp", ""))
    if not os.path.exists(grid_folder):
        os.makedirs(grid_folder)
    for month, vrts in vrt_months.items():
        try:
            del final
        except:
            pass
        out_file = os.path.join(grid_folder, os.path.basename(cur_grid).replace(".shp", f"_{month}.csv"))
        if not os.path.exists(out_file):
            curD = gpd.read_file(cur_grid)
            pbar = tqdm(vrts)
            pbar.set_description(f'Processing {os.path.basename(cur_grid).replace(".shp", "")} {month}')

            for cur_vrt in pbar:
                curR = rasterio.open(cur_vrt)
                if curD.crs != curR.crs:
                    curD = curD.to_crs(curR.crs)
                date = "_".join(cur_vrt.split("_")[-3:]).replace(".vrt", "")

                res = rMisc.zonalStats(curD, curR, rastType='C', unqVals=unq_vals)
                res = pd.DataFrame(res, columns=[f'{date}_{x}' for x in unq_vals])

                try:
                    final = final.join(res)                
                except:
                    final = res            
            final['GRID_ID'] = curD['GRID_ID']
            final.to_csv(out_file)

# %% [markdown]
# # Summarize Aggregates

# %% [markdown]
# ## Evaluate zonal stats

# %%
pd.read_csv?

# %%
# loop through all the zonal stats and calculate maximum counts
zonal_files = os.listdir(final_folder)
for z_file in zonal_files:
    inD = pd.read_csv(os.path.join(final_folder, z_file), index_col=0)
    print(z_file)
    print(inD.apply(get_max, axis=0))

# %%
inD.head()

# %% [markdown]
# ## extract extent of files

# %%
pt_files

# %%
# get extents of grid_files
all_res = []
for g_file in pt_files:
    inD = gpd.read_file(g_file)
    all_res.append([os.path.basename(g_file), inD.unary_union])

# %%
all_res2 = []
for key, items in vrt_months.items():
    for vrt in items:
        xx = rasterio.open(vrt)
        all_res2.append([os.path.basename(vrt), box(*xx.bounds)])

# %%
final_extents = gpd.GeoDataFrame(pd.DataFrame(all_res, columns=['File','geometry']), geometry='geometry', crs=inD.crs)
final_extents.to_file("GRIDS_Extents.geojson", driver="GeoJSON")

# %%
final_extents2 = gpd.GeoDataFrame(pd.DataFrame(all_res2, columns=['File','geometry']), geometry='geometry', crs=xx.crs)
final_extents2.to_file("VRT_Extents.geojson", driver="GeoJSON")

# %% [markdown]
# # DEBUGGING

# %%
run_zonal(grids[0], vrt_months['01'], '/home/wb411133/projects/WOFS_Walker/FUBAR_01.csv')
xx = pd.read_csv('/home/wb411133/projects/WOFS_Walker/FUBAR_01.csv', index_col=0)

def get_max(x):
    try:
        return(x.max())
    except:
        pass

list(xx.apply(get_max, axis=0))

# %%
for vrt in vrts:
    print(os.path.basename(vrt))
    xx = rasterio.open(vrt)
    data = xx.read()
    unique, counts = np.unique(data, return_counts=True)
    print(np.asarray((unique, counts)).T)
