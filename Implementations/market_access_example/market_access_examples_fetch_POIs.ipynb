# %% [markdown]
# # GOSTnets Market Access Examples: fetch OSM POIs

# %% [markdown]
# ### Import libraries

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os, inspect, logging, importlib

import geopandas as gpd
import pandas as pd
import numpy as np
import osmnx as ox
import networkx as nx
from shapely.ops import split, unary_union
from shapely.geometry import box, Point

import matplotlib.pyplot as plt

# %%
# Get reference to GOSTNets
sys.path.append(r'../../../GOSTnets')
import GOSTnets as gn

# %%
from GOSTnets.fetch_pois import *

# %% [markdown]
# ### check to make sure you are usng osmnx version 1.0.1 or above

# %%
import osmnx as ox 
ox.__version__
# Out:
# '1.0.1'

# %%
# import extent
city_extent = gpd.read_file("admin/Buffalo_City.shp")

# %%
# make sure crs is 4326
print(city_extent.crs)
# Out:
# epsg:4326

# %%
extent = box(*city_extent.total_bounds)

# %%
extent

# %% [markdown]
# ## We will extract OSM POIs
# There is a new way to create tags from before. We are following the same way OSMNX now does it with their geometry module. The GOSTnets fetch_pois module uses it as a dependency.

# %%
tags = {'amenity':['school', 'kindergarten','university', 'college']}

# %%
# create the OsmObject
schools_query = OsmObject('education', extent, tags)

# %%
schools_query

# %% [markdown]
# ### The advantage of using the GenerateOSMPOIs method is that it fetches nodes, ways, and relations

# %%
schools_query.GenerateOSMPOIs()
# Out:
# ../../../GOSTnets\GOSTnets\fetch_pois.py:79: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   polygons['geometry'] = polygons.centroid
# C:\Users\war-machine\Anaconda2\envs\gostnets2\lib\site-packages\geopandas\geoseries.py:158: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.Series(data, index=index, name=name, **kwargs)
#            unique_id       osmid element_type     amenity  \
# 0     node/621169044   621169044         node      school
# 1     node/621169045   621169045         node      school
# 2     node/621169047   621169047         node      school
# 3    node/1717717357  1717717357         node     college
# 4    node/1828180115  1828180115         node      school
# ..               ...         ...          ...         ...
# 124    way/392838382   392838382          way  university
# 125    way/865934585   865934585          way      school
# 126    way/865934586   865934586          way      school
# 127    way/865934604   865934604          way      school
# 128    way/871889335   871889335          way      school
#
#                         name                    geometry  wikidata  \
# 0    Port Rex Technical High  POINT (27.91170 -32.98514)       NaN
# 1           Hudson Park High  POINT (27.91586 -32.98572)  Q5928799
# 2        Hudson Park Primary  POINT (27.91603 -32.98316)       NaN
# 3    East London FET College  POINT (27.89951 -32.99601)       NaN
# 4     St. Johns Road Primary  POINT (27.89632 -33.00945)       NaN
# ..                       ...                         ...       ...
# 124  University of Fort Hare  POINT (27.42815 -32.86145)       NaN
# 125                      NaN  POINT (27.44307 -32.88653)       NaN
# 126                      NaN  POINT (27.44323 -32.88988)       NaN
# 127                      NaN  POINT (27.38356 -32.89457)       NaN
# 128                      NaN  POINT (27.41476 -32.88113)       NaN
#
#     designation source barrier  ... wikipedia building isced addr:postcode  \
# 0           NaN    NaN     NaN  ...       NaN      NaN   NaN           NaN
# 1           NaN    NaN     NaN  ...       NaN      NaN   NaN           NaN
# 2           NaN    NaN     NaN  ...       NaN      NaN   NaN           NaN
# 3           NaN    NaN     NaN  ...       NaN      NaN   NaN           NaN
# 4           NaN    NaN     NaN  ...       NaN      NaN   NaN           NaN
# ..          ...    ...     ...  ...       ...      ...   ...           ...
# 124         NaN    NaN     NaN  ...       NaN      NaN   NaN           NaN
# 125         NaN    NaN     NaN  ...       NaN      NaN   NaN           NaN
# 126         NaN    NaN     NaN  ...       NaN      NaN   NaN           NaN
# 127         NaN    NaN     NaN  ...       NaN      NaN   NaN           NaN
# 128         NaN    NaN     NaN  ...       NaN      NaN   NaN           NaN
#
#     addr:street email opening_hours phone website religion
# 0           NaN   NaN           NaN   NaN     NaN      NaN
# 1           NaN   NaN           NaN   NaN     NaN      NaN
# 2           NaN   NaN           NaN   NaN     NaN      NaN
# 3           NaN   NaN           NaN   NaN     NaN      NaN
# 4           NaN   NaN           NaN   NaN     NaN      NaN
# ..          ...   ...           ...   ...     ...      ...
# 124         NaN   NaN           NaN   NaN     NaN      NaN
# 125         NaN   NaN           NaN   NaN     NaN      NaN
# 126         NaN   NaN           NaN   NaN     NaN      NaN
# 127         NaN   NaN           NaN   NaN     NaN      NaN
# 128         NaN   NaN           NaN   NaN     NaN      NaN
#
# [129 rows x 22 columns]

# %%
schools_query.RemoveDupes(0.0005)
# Out:
# C:\Users\war-machine\Anaconda2\envs\gostnets2\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ../../../GOSTnets\GOSTnets\fetch_pois.py:95: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['buffer'] = gdf['geometry'].buffer(buf_width)
#     addr:postcode addr:street     amenity barrier  \
# 0             NaN         NaN      school     NaN
# 1             NaN         NaN      school     NaN
# 2             NaN         NaN      school     NaN
# 3             NaN         NaN     college     NaN
# 4             NaN         NaN      school     NaN
# ..            ...         ...         ...     ...
# 115           NaN         NaN  university     NaN
# 116           NaN         NaN      school     NaN
# 117           NaN         NaN      school     NaN
# 118           NaN         NaN      school     NaN
# 119           NaN         NaN      school     NaN
#
#                                                 buffer building created_by  \
# 0    POLYGON ((27.9121977 -32.9851427, 27.912195292...      NaN        NaN
# 1    POLYGON ((27.9163605 -32.9857187, 27.916358092...      NaN        NaN
# 2    POLYGON ((27.9165321 -32.9831628, 27.916529692...      NaN        NaN
# 3    POLYGON ((27.9000102 -32.9960097, 27.900007792...      NaN        NaN
# 4    POLYGON ((27.8968207 -33.0094526, 27.896818292...      NaN        NaN
# ..                                                 ...      ...        ...
# 115  POLYGON ((27.42865472444661 -32.86144644612616...      NaN        NaN
# 116  POLYGON ((27.44356719384164 -32.88652631501944...      NaN        NaN
# 117  POLYGON ((27.44373261532089 -32.88988057880312...      NaN        NaN
# 118  POLYGON ((27.3840606891516 -32.89456859897195,...      NaN        NaN
# 119  POLYGON ((27.41526270255177 -32.88112637432219...      NaN        NaN
#
#     designation element_type email  ...  \
# 0           NaN         node   NaN  ...
# 1           NaN         node   NaN  ...
# 2           NaN         node   NaN  ...
# 3           NaN         node   NaN  ...
# 4           NaN         node   NaN  ...
# ..          ...          ...   ...  ...
# 115         NaN          way   NaN  ...
# 116         NaN          way   NaN  ...
# 117         NaN          way   NaN  ...
# 118         NaN          way   NaN  ...
# 119         NaN          way   NaN  ...
#
#                                                  nodes opening_hours  \
# 0                                                  NaN           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4                                                  NaN           NaN
# ..                                                 ...           ...
# 115  [3960334801, 3960334802, 3960334803, 396033480...           NaN
# 116  [8071307802, 8071307801, 8071307800, 807130779...           NaN
# 117  [8071307815, 8071307814, 8071307813, 807130781...           NaN
# 118  [8071314108, 8071314107, 8071314106, 807131410...           NaN
# 119  [8121014599, 8121014598, 8121014597, 812101459...           NaN
#
#             osmid phone religion  source        unique_id website  wikidata  \
# 0    6.211690e+08   NaN      NaN     NaN   node/621169044     NaN       NaN
# 1    6.211690e+08   NaN      NaN     NaN   node/621169045     NaN  Q5928799
# 2    6.211690e+08   NaN      NaN     NaN   node/621169047     NaN       NaN
# 3    1.717717e+09   NaN      NaN     NaN  node/1717717357     NaN       NaN
# 4    1.828180e+09   NaN      NaN     NaN  node/1828180115     NaN       NaN
# ..            ...   ...      ...     ...              ...     ...       ...
# 115  3.928384e+08   NaN      NaN     NaN    way/392838382     NaN       NaN
# 116  8.659346e+08   NaN      NaN     NaN    way/865934585     NaN       NaN
# 117  8.659346e+08   NaN      NaN     NaN    way/865934586     NaN       NaN
# 118  8.659346e+08   NaN      NaN     NaN    way/865934604     NaN       NaN
# 119  8.718893e+08   NaN      NaN     NaN    way/871889335     NaN       NaN
#
#     wikipedia
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 115       NaN
# 116       NaN
# 117       NaN
# 118       NaN
# 119       NaN
#
# [120 rows x 23 columns]

# %%
# warning: might not want to include the 'osmid' field because it may contain lists
school_destinations = schools_query.df[['amenity','geometry','name']]
# Out:
# C:\Users\war-machine\Anaconda2\envs\gostnets2\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
school_destinations[:3]
# Out:
#   amenity                        geometry                     name
# 0  school  POINT (27.9116977 -32.9851427)  Port Rex Technical High
# 1  school  POINT (27.9158605 -32.9857187)         Hudson Park High
# 2  school  POINT (27.9160321 -32.9831628)      Hudson Park Primary

# %% [markdown]
# ### save the facilities as a shapefile

# %%
# if not os.path.exists(outputFolder + '/osm_infrastructure/OSM_schools.shp'):

# convert to GeoDataFrame
school_destinations_gpd = gpd.GeoDataFrame(school_destinations, crs = "epsg:4326", geometry = 'geometry')
#school_destinations_gpd.to_file(outputFolder + '/osm_schools.shp')
# or you can write to a CSV
school_destinations_gpd.to_csv('osm_schools.csv')
