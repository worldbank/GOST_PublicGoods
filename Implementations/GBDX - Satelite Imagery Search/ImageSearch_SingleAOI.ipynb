# %% [markdown]
# ### Library installation and script setup
# This box needs to only be run once. It builds the environment to carry out the rest of the analysis.

# %%
# Run one time only - install pip and unusual Libraries
import pip
import pandas as pd
import shapely
from shapely.wkt import loads
from shapely.geometry import box
from shapely.geometry import MultiPolygon
import time
import json
from gbdxtools import Interface
from gbdxtools.task import env
from gbdxtools import CatalogImage
gbdx = Interface()
# %matplotlib inline
import geopandas as gpd

# %% [markdown]
# ### Define AOI and bounding box of AOI from shapefile
# The user needs to have their Area of Interest ("AOI") defined as a one-polygon shapefile. This should be uploaded to the Jupyter server. Upload a polygon shapefile with only one feature. Save this file to the Jupyter server (click on the Jupyter logo, then click 'upload'). This step should be performed before running the next cell.

# %%
# determine if input is single point or shapefile
input_type = 'shapefile'

if input_type == 'point':
    from shapely.geometry import Point
    
    # Create shapely Point instance 
    point = Point((92.1443285, 21.2705219))
    
    # Make a square box around it using buffer method
    point = point.buffer(0.002, cap_style = 3)
    AOI = point
    
elif input_type == 'shapefile': 
    # Attach the name of uploaded file to the fname variable. If it is not 'shapefile.shp', change the name accordingly. 
    fname = 'Padma_1.shp' 

    # Create Area of Interest (AOI) object as a geopandas object; reproject to WGS84 if not already in WGS 84
    AOI = gpd.read_file(fname)
    crs_WGS84 = {'init' :'epsg:4326'}
    AOI = AOI.to_crs(crs_WGS84)

    # Redefine AOI as the first WKT object in the DataFrame (valid for 1-polygon objects only)
    AOI = AOI['geometry'].loc[0]

else: 
    print('** WARNING: Failure to determine adequate input data type **')
    AOI = ''
    
# Create bboxx - the square shaped box which will always contain the AOI.
bboxx = []
for coord in range(0,len(AOI.bounds)): 
    bboxx.append(AOI.bounds[coord])

# Print to screen - AOI and bboxx
print 'AOI: || ', AOI, '\n\nbboxx: || ', bboxx
# Out:
# AOI: ||  POLYGON ((90.13814810386185 23.38893329021568, 90.3320378864282 23.75250366283122, 90.4669528601306 23.70591047355641, 90.29164418172688 23.32069846171082, 90.13814810386185 23.38893329021568))
#
# bboxx: ||  [90.13814810386185, 23.320698461710816, 90.4669528601306, 23.75250366283122]

# %% [markdown]
# ### Perform Initial Vector Search: AOI Vector Against Image Catalog for All Potential Images
# Given the calculations conducted in the previous step, this cell queries the DigitalGlobe image database based on the vector footprint of the AOI defined above, and returns a list of catalog IDs which at least partially cover the AOI. As default, it returns up to 1000 images, with a cloud cover less than 25%.

# %%
# Define search function. Returns up to 1000 images where cloud cover smaller than 25%
def search_unordered(bbox, _type, count=1000, cloud_cover=25):
    aoi = AOI.wkt
    query = "item_type:{} AND item_type:DigitalGlobeAcquisition".format(_type)
    query += " AND attributes.cloudCover_int:<{}".format(cloud_cover)
    return gbdx.vectors.query(aoi, query, count=count)

# Run search on Area of Interest (AOI). Passes in AOI in Well Known Text format (wkt)
records = search_unordered(AOI.wkt, 'DigitalGlobeAcquisition')

# Create list object of all catalog IDs returned in search
ids = [r['properties']['attributes']['catalogID'] for r in records]

# Print length of list of catalogi IDs (number of unique images)
print 'Unique images found: %s' % len(ids)
# Out:
# Unique images found: 253

# %% [markdown]
# ### Generate CSV of images that match criteria
# At this point, the script generates a .csv file with the key metadata about the image which will be used for further processing later. This is the definitive database for the given AOI. No filtering yet takes place.
#
# Key calculated statistics include: the area where the scene and the AOI don't overlap (AA), the corresponding overlap with the image (BB), the fraction of the AOI covered (frac), and the binary flag for whether the image is yet in IDAHO.

# %%
# %matplotlib inline

# Define Counters
l = 0    # number of non-IDAHO images
scenes = [] # list containing metadata dictionaries of all scenes in our AOI 

# Toggle for printing images to screen
download_thumbnails = 0

# Loop catalog IDs
for i in ids:
    
    # Fetch metadata dictionary for each catalog ID in ids list
    r = gbdx.catalog.get(i)
    
    # Check location of ID - is it in IDAHO?
    location = gbdx.catalog.get_data_location(i)
    
    # Defines IDAHO variable as binary 1 / 0 depending on whether it is in IDAHO already or not
    if location == 'not_delivered':
        l = l + 1
        idaho = 0
    else:
        idaho = 1
    
        # Download image if image in IDAHO and toggle on
        if download_thumbnails == 1:
            image = CatalogImage(i, band_type="MS", bbox=bboxx)
            image.plot(w=10, h=10)
        else:
            pass
    
    # Print statement to consol for key image variables
    print 'ID: %s, Timestamp: %s, Cloud Cover: %s, Image bands: %s, IDAHO: %s' % (i,r['properties']['timestamp'],r['properties']['cloudCover'],r['properties']['imageBands'],idaho)
    
    # Calculate the percentage overlap with our AOI for each scene
    # load as a Shapely object the wkt representation of the scene footprint
    footprint = r['properties']['footprintWkt']
    shapely_footprint = shapely.wkt.loads(footprint)
    
    # Calculate the object that represents the difference between the AOI and the scene footprint 
    AA = AOI.difference(shapely_footprint)
    
    # Define frac as the fraction, between 0 and 1, of the AOI that the scene covers
    frac = 1 - ((AA).area / AOI.area)
    
    # Create BB - the proxy for the useful area. IF scene entirely contains AOI, then BB = AOI, else it is the intersection 
    # of the scene footprint and the AOI
    BB = AOI 
    if frac < 1:
        BB = AOI - AA
    #shapely_footprint.intersection(AOI)
    # Similarly, AA, the difference area between AOI and the scene, can be set to null if the scene contains 100% of the AOI 
    if frac == 1:
        AA = ""
        
    # Append key metadata to list obejct 'scenes' for the current scene, as a dictionary. This then moves into the pandas dataframe.
    # Several objects here are from DigitalGlobe's metadata dictionary (anything with an r start)
    scenes.append({
        'ID':i, 
        'TimeStamp':r['properties']['timestamp'],
        'CloudCover':r['properties']['cloudCover'],
        'ImageBands':r['properties']['imageBands'],
        'On_IDAHO':idaho,
        'browseURL': r['properties']['browseURL'],
        'Overlap_%': frac * 100,
        'PanResolution': r['properties']['panResolution'],
        'MultiResolution': r['properties']['multiResolution'],
        'OffNadirAngle': r['properties']['offNadirAngle'],
        'Sensor':r['properties']['sensorPlatformName'],
        'Full_scene_WKT':r['properties']['footprintWkt'],
        'missing_area_WKT':AA,
        'useful_area_WKT':BB
        })
    
# Summary Statistics - show totals for images, both in IDAHO and currenlty unavailable images. 
print 'Number of catalog IDs not available in IDAHO: %s' % l
print 'Number of catalog IDs available in IDAHO: %s' % (len(ids) - l)

# Define column order for dataframe of search results
cols = ['ID','Sensor','ImageBands','TimeStamp','CloudCover','Overlap_%','PanResolution','MultiResolution','OffNadirAngle','On_IDAHO','browseURL','Full_scene_WKT','useful_area_WKT','missing_area_WKT']

#Generate pandas dataframe from results
out = pd.DataFrame(scenes,columns = cols)
# Out:
# ID: 103001005F603400, Timestamp: 2016-11-01T04:42:55.314Z, Cloud Cover: 11, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1040010013229A00, Timestamp: 2015-11-07T04:57:15.397Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 103001005F73F900, Timestamp: 2016-11-01T04:41:30.164Z, Cloud Cover: 9, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1020010009B7BE00, Timestamp: 2009-09-29T04:51:58.816Z, Cloud Cover: 19, Image bands: PAN, IDAHO: 0
# ID: 1020010009C9D500, Timestamp: 2009-09-29T04:50:55.416Z, Cloud Cover: 21, Image bands: PAN, IDAHO: 0
# ID: 1020010009CB7900, Timestamp: 2009-10-12T04:45:38.980Z, Cloud Cover: 5, Image bands: PAN, IDAHO: 0
# ID: 103001000386FD00, Timestamp: 2009-12-06T04:41:55.949Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 10400100250FF800, Timestamp: 2016-12-30T04:53:49.612Z, Cloud Cover: 2, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 101001000362D500, Timestamp: 2004-11-13T04:46:46.663Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1010010005624500, Timestamp: 2006-12-20T04:55:59.726Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 102001000A961E00, Timestamp: 2009-11-06T04:58:46.386Z, Cloud Cover: 11, Image bands: PAN, IDAHO: 0
# ID: 10100100055CD700, Timestamp: 2006-12-07T05:01:08.097Z, Cloud Cover: 2, Image bands: PAN_MS1, IDAHO: 0
# ID: 1040010016437E00, Timestamp: 2016-01-03T04:59:08.739Z, Cloud Cover: 6, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 10504100043E7100, Timestamp: 2013-12-11T04:36:16.484Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1030010022C30500, Timestamp: 2013-04-06T05:06:30.621Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1040010016136A00, Timestamp: 2016-01-16T05:03:32.775Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1050410002F87400, Timestamp: 2009-06-25T04:37:51.085Z, Cloud Cover: 15, Image bands: PAN_MS1, IDAHO: 0
# ID: 1010010005646700, Timestamp: 2006-12-25T05:01:24.116Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 101001000A52C400, Timestamp: 2009-09-26T04:44:35.644Z, Cloud Cover: 11, Image bands: PAN_MS1, IDAHO: 0
# ID: 102001000ABA6300, Timestamp: 2009-11-06T04:58:54.186Z, Cloud Cover: 4, Image bands: PAN, IDAHO: 0
# ID: 1010010004C3D500, Timestamp: 2006-01-22T04:54:59.680Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1010010005511C00, Timestamp: 2006-11-14T04:55:05.193Z, Cloud Cover: 21, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050410000F0BA00, Timestamp: 2011-12-04T04:32:57.285Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 103001004C66F900, Timestamp: 2015-12-09T04:41:43.545Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1010010005538200, Timestamp: 2006-11-19T05:00:22.957Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1020010009CC7C00, Timestamp: 2009-10-29T04:48:08.833Z, Cloud Cover: 10, Image bands: PAN, IDAHO: 0
# ID: 10100100055A8D00, Timestamp: 2006-12-02T04:55:38.716Z, Cloud Cover: 1, Image bands: PAN_MS1, IDAHO: 0
# ID: 10100100001B0500, Timestamp: 2002-02-06T04:44:12.036Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 103001004A0CD700, Timestamp: 2015-10-10T04:52:40.187Z, Cloud Cover: 19, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1020010001491C00, Timestamp: 2007-12-14T04:33:51.816Z, Cloud Cover: 0, Image bands: PAN, IDAHO: 0
# ID: 10100100002F9C00, Timestamp: 2002-03-14T04:43:53.144Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1010010005B16600, Timestamp: 2007-06-18T05:00:29.212Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 10200100414DCF00, Timestamp: 2015-09-12T06:24:35.370Z, Cloud Cover: 17, Image bands: PAN, IDAHO: 0
# ID: 1010010004ACDA00, Timestamp: 2005-11-29T04:52:25.816Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 102001000191EC00, Timestamp: 2008-01-18T04:29:46.020Z, Cloud Cover: 0, Image bands: PAN, IDAHO: 0
# ID: 104001002805C000, Timestamp: 2017-02-25T05:12:09.052Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 10100100056BBB00, Timestamp: 2007-01-12T05:01:55.193Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 10300100623FD700, Timestamp: 2017-01-08T04:32:15.835Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1050410012684B00, Timestamp: 2015-03-25T04:42:28.085Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 103001006300F000, Timestamp: 2017-01-08T04:32:27.435Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1040010029BE3B00, Timestamp: 2017-02-25T05:12:21.353Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 1
# ID: 1010010007619100, Timestamp: 2007-11-22T04:57:18.642Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1010010007832200, Timestamp: 2007-12-28T04:58:20.245Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 102001000E020300, Timestamp: 2010-07-28T04:56:58.185Z, Cloud Cover: 13, Image bands: PAN, IDAHO: 0
# ID: 10400100289CA900, Timestamp: 2017-02-12T05:02:33.065Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 104001002C054900, Timestamp: 2017-05-04T05:08:28.000Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1050410000FF6B00, Timestamp: 2013-02-10T04:44:03.685Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 105041000F4D7C00, Timestamp: 2013-12-11T04:35:16.085Z, Cloud Cover: 1, Image bands: PAN_MS1, IDAHO: 0
# ID: 105041000F600F00, Timestamp: 2013-12-30T04:37:51.084Z, Cloud Cover: 4, Image bands: PAN_MS1, IDAHO: 0
# ID: 102001005F38BB00, Timestamp: 2017-04-16T07:41:36.000Z, Cloud Cover: 0, Image bands: PAN, IDAHO: 0
# ID: 101001000B66FA00, Timestamp: 2010-04-07T04:35:11.043Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 101001000B4DA300, Timestamp: 2010-03-20T04:35:34.843Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1020010020965600, Timestamp: 2013-03-16T04:32:07.673Z, Cloud Cover: 0, Image bands: PAN, IDAHO: 0
# ID: 10200100045C9100, Timestamp: 2008-11-22T04:52:39.979Z, Cloud Cover: 0, Image bands: PAN, IDAHO: 0
# ID: 1020010022E6A200, Timestamp: 2013-06-17T04:44:52.630Z, Cloud Cover: 24, Image bands: PAN, IDAHO: 0
# ID: 103001003942F400, Timestamp: 2014-11-05T05:04:50.909Z, Cloud Cover: 4, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 105001000207DC00, Timestamp: 2015-11-05T04:30:30.885Z, Cloud Cover: 21, Image bands: PAN_MS1, IDAHO: 0
# ID: 105041000F552500, Timestamp: 2013-12-19T04:30:42.685Z, Cloud Cover: 1, Image bands: PAN_MS1, IDAHO: 0
# ID: 105041000F552700, Timestamp: 2013-12-19T04:31:34.885Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050410004C52200, Timestamp: 2014-01-18T04:38:52.085Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 10504100014E5A00, Timestamp: 2011-04-04T04:43:45.085Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050410001EE4500, Timestamp: 2010-02-27T04:35:59.285Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1040010028B08100, Timestamp: 2017-02-12T05:03:01.015Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 103001004F37FA00, Timestamp: 2016-01-02T04:56:03.879Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1050010004815800, Timestamp: 2016-05-23T04:46:52.285Z, Cloud Cover: 15, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050410001577A00, Timestamp: 2011-04-04T04:42:54.085Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 105041001061C900, Timestamp: 2014-04-23T04:38:21.085Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1010010009245A00, Timestamp: 2009-02-04T04:48:21.644Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 10504100010DA800, Timestamp: 2013-02-10T04:43:03.285Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050410004A4E400, Timestamp: 2013-12-19T04:30:42.685Z, Cloud Cover: 3, Image bands: PAN_MS1, IDAHO: 0
# ID: 1030010063CEDE00, Timestamp: 2017-01-08T04:30:58.785Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1010010008C79D00, Timestamp: 2008-11-06T04:48:53.243Z, Cloud Cover: 1, Image bands: PAN_MS1, IDAHO: 0
# ID: 1010010008CCFC00, Timestamp: 2008-11-11T04:54:07.644Z, Cloud Cover: 1, Image bands: PAN_MS1, IDAHO: 0
# ID: 105041001048FF00, Timestamp: 2014-04-04T04:41:31.085Z, Cloud Cover: 20, Image bands: PAN_MS1, IDAHO: 0
# ID: 10504100012BC500, Timestamp: 2010-12-26T04:37:26.885Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050410004A51900, Timestamp: 2013-12-19T04:31:34.885Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 104001002682D800, Timestamp: 2017-01-25T05:11:31.435Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 102001000929F300, Timestamp: 2009-09-29T04:51:08.016Z, Cloud Cover: 21, Image bands: PAN, IDAHO: 0
# ID: 102001000BE1DE00, Timestamp: 2010-01-30T05:01:51.385Z, Cloud Cover: 0, Image bands: PAN, IDAHO: 0
# ID: 1010010008DDA500, Timestamp: 2008-11-29T04:54:11.438Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050410004B18900, Timestamp: 2013-12-22T04:42:13.684Z, Cloud Cover: 7, Image bands: PAN_MS1, IDAHO: 0
# ID: 1010010009114B00, Timestamp: 2009-01-17T04:48:34.642Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 10500100078B6400, Timestamp: 2016-12-21T04:39:02.685Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 103001001F9E0000, Timestamp: 2013-02-22T04:50:37.790Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1050410001313700, Timestamp: 2010-12-26T04:36:38.485Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 101001000AE71E00, Timestamp: 2010-01-07T04:37:07.846Z, Cloud Cover: 23, Image bands: PAN_MS1, IDAHO: 0
# ID: 102001002DC4ED00, Timestamp: 2014-03-20T04:48:18.027Z, Cloud Cover: 0, Image bands: PAN, IDAHO: 0
# ID: 101001000ACEEB00, Timestamp: 2009-12-20T04:38:20.643Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 10200100090D2A00, Timestamp: 2009-10-12T04:46:37.980Z, Cloud Cover: 6, Image bands: PAN, IDAHO: 0
# ID: 102001000990DB00, Timestamp: 2009-09-12T04:50:56.163Z, Cloud Cover: 23, Image bands: PAN, IDAHO: 0
# ID: 1020010009AE7A00, Timestamp: 2009-11-06T04:59:40.986Z, Cloud Cover: 8, Image bands: PAN, IDAHO: 0
# ID: 1050410002F8BF00, Timestamp: 2009-06-25T04:38:39.885Z, Cloud Cover: 19, Image bands: PAN_MS1, IDAHO: 0
# ID: 10200100094F8800, Timestamp: 2009-10-29T04:47:08.033Z, Cloud Cover: 6, Image bands: PAN, IDAHO: 0
# ID: 101001000A8A5300, Timestamp: 2009-11-01T04:44:17.442Z, Cloud Cover: 5, Image bands: PAN_MS1, IDAHO: 0
# ID: 1020010009A13800, Timestamp: 2009-09-29T04:51:51.216Z, Cloud Cover: 24, Image bands: PAN, IDAHO: 0
# ID: 10300100039C1100, Timestamp: 2010-01-24T04:54:00.389Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1030010003D0A300, Timestamp: 2010-01-27T04:45:03.593Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1040010046238600, Timestamp: 2019-01-25T04:52:38.000Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 1
# ID: 1040010013659A00, Timestamp: 2015-11-07T04:58:02.647Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 10504100043DA700, Timestamp: 2013-12-11T04:35:16.085Z, Cloud Cover: 4, Image bands: PAN_MS1, IDAHO: 0
# ID: 102001000AEB9200, Timestamp: 2009-11-06T04:59:47.786Z, Cloud Cover: 16, Image bands: PAN, IDAHO: 0
# ID: 1050010002040400, Timestamp: 2015-11-03T04:57:49.485Z, Cloud Cover: 18, Image bands: PAN_MS1, IDAHO: 0
# ID: 10504100029A9D00, Timestamp: 2013-04-25T04:38:40.684Z, Cloud Cover: 6, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050010002040200, Timestamp: 2015-11-03T04:56:51.485Z, Cloud Cover: 16, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050410002B36F00, Timestamp: 2013-02-07T04:34:03.685Z, Cloud Cover: 22, Image bands: PAN_MS1, IDAHO: 0
# ID: 10400100279C7100, Timestamp: 2016-12-30T04:52:49.212Z, Cloud Cover: 1, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 103001001D94D600, Timestamp: 2012-11-02T05:18:17.229Z, Cloud Cover: 24, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 10400100147DDA00, Timestamp: 2015-11-07T04:56:57.747Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 10200100215D9200, Timestamp: 2013-04-06T04:38:12.337Z, Cloud Cover: 0, Image bands: PAN, IDAHO: 0
# ID: 1030010054688100, Timestamp: 2016-03-24T04:33:00.121Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 10200100424E2200, Timestamp: 2015-09-08T06:18:37.430Z, Cloud Cover: 15, Image bands: PAN, IDAHO: 0
# ID: 103001004ABAD300, Timestamp: 2015-10-16T04:31:12.396Z, Cloud Cover: 23, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1040010038BFAB00, Timestamp: 2018-02-27T05:02:04.000Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1040010039461800, Timestamp: 2018-02-27T05:02:17.000Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 1
# ID: 1020010011289700, Timestamp: 2010-12-28T05:03:19.213Z, Cloud Cover: 0, Image bands: PAN, IDAHO: 0
# ID: 103001000460DE00, Timestamp: 2010-03-09T04:50:41.915Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 104001001FADB200, Timestamp: 2016-08-04T04:56:41.168Z, Cloud Cover: 4, Image bands: PAN_MS1_MS2, IDAHO: 1
# ID: 101001000C626400, Timestamp: 2010-10-04T04:29:06.644Z, Cloud Cover: 5, Image bands: PAN_MS1, IDAHO: 0
# ID: 1030010062BFA000, Timestamp: 2016-12-09T04:39:15.591Z, Cloud Cover: 1, Image bands: PAN_MS1_MS2, IDAHO: 1
# ID: 10500100075D2700, Timestamp: 2016-12-02T04:42:18.485Z, Cloud Cover: 2, Image bands: PAN_MS1, IDAHO: 0
# ID: 103001001F6E4D00, Timestamp: 2013-02-22T04:50:20.188Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 103001004996D800, Timestamp: 2015-09-27T04:31:56.768Z, Cloud Cover: 3, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1030010054CD5E00, Timestamp: 2016-04-28T04:42:00.820Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 101001000B1A6300, Timestamp: 2010-02-12T04:36:36.243Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050010006C0FD00, Timestamp: 2016-10-22T04:34:59.085Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1020010043CB7900, Timestamp: 2015-09-25T06:19:02.338Z, Cloud Cover: 17, Image bands: PAN, IDAHO: 0
# ID: 10400100389BEE00, Timestamp: 2018-02-27T05:02:30.000Z, Cloud Cover: 1, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 10400100138CE100, Timestamp: 2015-11-07T04:58:13.847Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1040010001BBC300, Timestamp: 2014-09-15T04:28:41.199Z, Cloud Cover: 19, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1020010044C54800, Timestamp: 2015-09-29T06:23:59.478Z, Cloud Cover: 21, Image bands: PAN, IDAHO: 0
# ID: 1030010069BD5600, Timestamp: 2017-05-15T04:42:24.000Z, Cloud Cover: 7, Image bands: PAN_MS1_MS2, IDAHO: 1
# ID: 104001000196E300, Timestamp: 2014-09-15T04:28:23.499Z, Cloud Cover: 19, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 10200100425C6800, Timestamp: 2015-08-05T06:20:12.993Z, Cloud Cover: 21, Image bands: PAN, IDAHO: 0
# ID: 102001000A392700, Timestamp: 2010-01-30T05:02:36.585Z, Cloud Cover: 0, Image bands: PAN, IDAHO: 0
# ID: 10200100674B0E00, Timestamp: 2017-11-11T07:34:22.000Z, Cloud Cover: 0, Image bands: PAN, IDAHO: 1
# ID: 102001006A3FC400, Timestamp: 2017-11-11T07:33:41.000Z, Cloud Cover: 0, Image bands: PAN, IDAHO: 1
# ID: 102001002F90CE00, Timestamp: 2014-05-23T04:46:21.109Z, Cloud Cover: 12, Image bands: PAN, IDAHO: 0
# ID: 101001000B467600, Timestamp: 2010-03-15T04:30:45.641Z, Cloud Cover: 15, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050410012640600, Timestamp: 2015-03-22T04:33:50.485Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 10504100108C8500, Timestamp: 2014-05-23T04:40:05.684Z, Cloud Cover: 13, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050410001EC1E00, Timestamp: 2010-03-02T04:44:19.885Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 10504100100C7C00, Timestamp: 2014-02-14T04:34:10.885Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 105041000F72BC00, Timestamp: 2014-01-18T04:38:25.685Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 105041000F72BD00, Timestamp: 2014-01-18T04:38:52.085Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 102001000E93AA00, Timestamp: 2010-10-04T04:58:14.421Z, Cloud Cover: 17, Image bands: PAN, IDAHO: 0
# ID: 1050410004BC4000, Timestamp: 2014-01-26T04:34:20.485Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050410010149000, Timestamp: 2014-02-25T04:41:01.085Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1030010004448D00, Timestamp: 2010-03-23T04:40:42.534Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 10300100047C2A00, Timestamp: 2010-04-03T04:40:10.250Z, Cloud Cover: 15, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 104001000526B400, Timestamp: 2014-11-30T04:28:41.983Z, Cloud Cover: 1, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1050410004C66F00, Timestamp: 2014-01-18T04:37:57.685Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050410004C62F00, Timestamp: 2014-01-18T04:39:17.485Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050410004C63000, Timestamp: 2014-01-18T04:38:25.685Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 103001002E12D700, Timestamp: 2014-03-20T04:49:37.604Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 103001002A86C200, Timestamp: 2013-12-20T05:05:05.440Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1050410004BE5400, Timestamp: 2014-01-26T04:33:29.484Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 102001000F655500, Timestamp: 2010-10-04T04:58:25.021Z, Cloud Cover: 12, Image bands: PAN, IDAHO: 0
# ID: 105041000F7ACB00, Timestamp: 2014-01-26T04:34:20.485Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 10504100107DCD00, Timestamp: 2014-05-12T04:36:44.485Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1040010029BF9100, Timestamp: 2017-02-25T05:11:53.353Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 103001005D88E800, Timestamp: 2016-11-09T04:46:58.576Z, Cloud Cover: 9, Image bands: PAN_MS1_MS2, IDAHO: 1
# ID: 105041000F4D7E00, Timestamp: 2013-12-11T04:36:16.484Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 10504100101F3000, Timestamp: 2014-03-05T04:35:12.485Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1010010012782000, Timestamp: 2014-03-19T04:01:18.892Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 10400100282CF600, Timestamp: 2017-02-12T05:02:46.766Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 1
# ID: 1050010004599D00, Timestamp: 2016-05-12T04:43:47.285Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 10200100228EF800, Timestamp: 2013-05-26T04:57:59.396Z, Cloud Cover: 14, Image bands: PAN, IDAHO: 0
# ID: 1050410001578C00, Timestamp: 2011-04-12T04:33:54.685Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1030010065669200, Timestamp: 2017-02-17T04:53:58.493Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 104001002D863400, Timestamp: 2017-06-10T05:03:42.000Z, Cloud Cover: 18, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 105041000F600D00, Timestamp: 2013-12-30T04:36:48.685Z, Cloud Cover: 7, Image bands: PAN_MS1, IDAHO: 0
# ID: 1010010011574600, Timestamp: 2013-04-25T03:46:39.921Z, Cloud Cover: 2, Image bands: PAN_MS1, IDAHO: 0
# ID: 102001002D185E00, Timestamp: 2014-05-23T04:46:08.955Z, Cloud Cover: 13, Image bands: PAN, IDAHO: 0
# ID: 102001001D003B00, Timestamp: 2012-12-16T04:48:50.172Z, Cloud Cover: 4, Image bands: PAN, IDAHO: 0
# ID: 10504100029ADB00, Timestamp: 2013-04-25T04:37:49.285Z, Cloud Cover: 3, Image bands: PAN_MS1, IDAHO: 0
# ID: 103001001C88AB00, Timestamp: 2012-10-28T05:01:57.750Z, Cloud Cover: 5, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 104001002D930400, Timestamp: 2017-05-23T05:13:59.000Z, Cloud Cover: 19, Image bands: PAN_MS1_MS2, IDAHO: 1
# ID: 10300100045EB500, Timestamp: 2010-04-22T04:46:57.476Z, Cloud Cover: 16, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1030010063C1EE00, Timestamp: 2017-01-08T04:31:14.836Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1030010064456900, Timestamp: 2017-01-29T04:56:08.165Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1050410001238D00, Timestamp: 2010-11-04T04:42:55.685Z, Cloud Cover: 3, Image bands: PAN_MS1, IDAHO: 0
# ID: 102001001EA9AE00, Timestamp: 2013-01-24T04:34:31.218Z, Cloud Cover: 0, Image bands: PAN, IDAHO: 0
# ID: 104001002519E300, Timestamp: 2016-11-17T04:58:06.857Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 1
# ID: 1030010064CCE300, Timestamp: 2017-01-29T04:55:43.965Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 1
# ID: 10504100100C7E00, Timestamp: 2014-02-14T04:35:19.485Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 10500100078B6600, Timestamp: 2016-12-21T04:40:13.685Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 10400100206C0700, Timestamp: 2016-08-04T04:57:39.667Z, Cloud Cover: 5, Image bands: PAN_MS1_MS2, IDAHO: 1
# ID: 103001002F4CBC00, Timestamp: 2014-03-28T04:55:53.347Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 10300100771CF900, Timestamp: 2017-12-26T04:57:05.000Z, Cloud Cover: 1, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1030010076B39000, Timestamp: 2017-12-26T04:56:28.000Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 105041000F7ACA00, Timestamp: 2014-01-26T04:33:29.484Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 103001004F206000, Timestamp: 2016-01-13T04:49:51.346Z, Cloud Cover: 3, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1050410000541600, Timestamp: 2012-02-19T04:37:56.085Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1020010019491600, Timestamp: 2012-02-05T05:00:27.175Z, Cloud Cover: 0, Image bands: PAN, IDAHO: 0
# ID: 104001001B9CB800, Timestamp: 2016-04-13T04:55:08.385Z, Cloud Cover: 23, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 10300100395F5000, Timestamp: 2014-10-23T04:45:33.542Z, Cloud Cover: 20, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 102001002B73B500, Timestamp: 2014-04-28T04:33:07.642Z, Cloud Cover: 0, Image bands: PAN, IDAHO: 0
# ID: 105041000F72BB00, Timestamp: 2014-01-18T04:37:57.685Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 105041000F72BE00, Timestamp: 2014-01-18T04:39:17.485Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050410010009C00, Timestamp: 2014-01-29T04:45:14.685Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 105041000092D500, Timestamp: 2011-04-15T04:43:33.085Z, Cloud Cover: 1, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050410001543000, Timestamp: 2011-04-12T04:34:54.685Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 102001002DEBF500, Timestamp: 2014-04-28T04:33:56.670Z, Cloud Cover: 0, Image bands: PAN, IDAHO: 0
# ID: 102001001DB3AC00, Timestamp: 2012-10-22T04:43:36.187Z, Cloud Cover: 1, Image bands: PAN, IDAHO: 0
# ID: 10300100638BF600, Timestamp: 2017-01-02T04:53:14.026Z, Cloud Cover: 3, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 10504100009B5A00, Timestamp: 2011-04-15T04:44:23.685Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1030010077677700, Timestamp: 2017-12-26T04:56:47.000Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 1
# ID: 1040010001588600, Timestamp: 2014-09-15T04:29:19.949Z, Cloud Cover: 16, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1050010007244600, Timestamp: 2016-11-10T04:33:38.285Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 10500100075D2600, Timestamp: 2016-12-02T04:41:18.285Z, Cloud Cover: 8, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050010008039200, Timestamp: 2017-01-23T04:51:47.285Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 101001000E6DDE00, Timestamp: 2011-11-08T04:14:19.642Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1040010033139C00, Timestamp: 2017-10-31T04:58:33.000Z, Cloud Cover: 1, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 104001002DD42400, Timestamp: 2017-05-22T04:58:45.000Z, Cloud Cover: 21, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 104001002F768E00, Timestamp: 2017-06-23T05:12:20.329Z, Cloud Cover: 23, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1020010067C1DC00, Timestamp: 2017-10-16T07:41:30.000Z, Cloud Cover: 20, Image bands: PAN, IDAHO: 0
# ID: 1030010075BC3400, Timestamp: 2017-12-23T05:07:07.000Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 10504100005CFE00, Timestamp: 2012-02-22T04:47:04.685Z, Cloud Cover: 2, Image bands: PAN_MS1, IDAHO: 0
# ID: 10504100005F5000, Timestamp: 2012-01-17T04:35:42.885Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1050410000572900, Timestamp: 2012-02-19T04:38:47.284Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 10504100005D4400, Timestamp: 2012-01-17T04:36:34.685Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1030010069081800, Timestamp: 2017-05-15T04:42:09.000Z, Cloud Cover: 8, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 10504100005F9500, Timestamp: 2012-01-28T04:37:29.685Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 104001003CBED000, Timestamp: 2018-04-25T05:08:21.000Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 104001003D280A00, Timestamp: 2018-04-25T05:08:34.000Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 1
# ID: 103001000F5E0100, Timestamp: 2012-01-28T04:58:43.563Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 102001001E0E9500, Timestamp: 2012-10-22T04:42:41.787Z, Cloud Cover: 3, Image bands: PAN, IDAHO: 0
# ID: 1030010011388F00, Timestamp: 2012-02-27T04:54:37.205Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 102001007AAB6200, Timestamp: 2018-10-05T07:31:18.000Z, Cloud Cover: 17, Image bands: PAN, IDAHO: 0
# ID: 103001001DCBAB00, Timestamp: 2012-12-02T05:12:21.771Z, Cloud Cover: 1, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 102001001EA0D600, Timestamp: 2012-10-22T04:43:43.987Z, Cloud Cover: 0, Image bands: PAN, IDAHO: 0
# ID: 1030010085896800, Timestamp: 2018-10-24T04:54:23.000Z, Cloud Cover: 4, Image bands: PAN_MS1_MS2, IDAHO: 1
# ID: 1030010086BC5500, Timestamp: 2018-10-24T04:55:47.000Z, Cloud Cover: 3, Image bands: PAN_MS1_MS2, IDAHO: 1
# ID: 10300100181FF500, Timestamp: 2012-05-10T05:05:41.183Z, Cloud Cover: 18, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 102001001E417D00, Timestamp: 2012-10-22T04:42:54.387Z, Cloud Cover: 1, Image bands: PAN, IDAHO: 0
# ID: 1040010037380300, Timestamp: 2018-01-21T05:10:14.000Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1040010038438F00, Timestamp: 2018-01-21T05:09:42.000Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 10400100378C8600, Timestamp: 2018-01-21T05:09:57.000Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 1
# ID: 10504100005EE300, Timestamp: 2012-02-22T04:47:27.484Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 13ff9a0f-e846-4ab3-a664-99cc33f298d9-inv, Timestamp: 2017-11-27T04:37:17.000Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 104001004459CF00, Timestamp: 2018-11-24T05:04:56.000Z, Cloud Cover: 1, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 1040010045AEE400, Timestamp: 2018-11-24T05:04:45.000Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 104001004357BF00, Timestamp: 2018-11-24T05:05:35.000Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 5a2d33a6-3438-465a-828b-617510aea1b9-inv, Timestamp: 2018-11-27T05:01:43.000Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: b0098647-5222-4a86-97fb-1eaa78f43957-inv, Timestamp: 2018-12-09T04:52:15.000Z, Cloud Cover: 2, Image bands: PAN_MS1, IDAHO: 0
# ID: 38005cd8-214f-4334-ab48-52f30eee36fd-inv, Timestamp: 2018-12-09T04:51:34.000Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1030010088A00600, Timestamp: 2018-12-01T04:58:45.000Z, Cloud Cover: 0, Image bands: PAN_MS1_MS2, IDAHO: 0
# ID: 4ab888b9-9eef-4498-a754-d0c3007cf56a-inv, Timestamp: 2018-12-09T04:51:53.000Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 49c562a8-02c8-47e0-9def-92d730cccc7b-inv, Timestamp: 2018-11-26T04:45:24.000Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: e51336ff-6ba6-485c-aadf-946f19fac11e-inv, Timestamp: 2018-04-14T04:42:44.000Z, Cloud Cover: 23, Image bands: PAN_MS1, IDAHO: 0
# ID: 04876860-4bf8-40bb-84d1-4e345e5862b8-inv, Timestamp: 2018-01-23T04:55:27.000Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: 1aa91bfe-d36c-43cd-8ce0-bd9c471fd27a-inv, Timestamp: 2018-04-13T04:27:59.000Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# ID: d6a00ef0-9da8-4064-847e-413b454383bb-inv, Timestamp: 2018-01-23T04:55:48.000Z, Cloud Cover: 0, Image bands: PAN_MS1, IDAHO: 0
# Number of catalog IDs not available in IDAHO: 234
# Number of catalog IDs available in IDAHO: 19

# %% [markdown]
# ### Perform Categorical Search: Remove Disqualified Images
# Performs pandas .loc operations to cut out scenes which don't meet the criteria specified by the 'cutoff' series of variables. Define these in-script in the '# Define categorical search parameters' section.

# %%
# Convert Timestamp field to pandas DateTime object
out['TS'] = out['TimeStamp'].apply(lambda x: pd.Timestamp(x))

# Add separate date and time columns for easy interpretation
string = out['TimeStamp'].str.split('T')
out['Date'] = string.str.get(0)
out['Time'] = string.str.get(1)

# Define categorical search parameters
cutoff_cloud_cover = 2   # images with CC over this threshold discarded
cutoff_overlap = 0     # images with AOI overlap below this threshold discarded. [N.b.: keep small if AOI large.]
cutoff_date_upper = '1-Jan-19'  # images newer than this date discarded
cutoff_date_lower = '1-Jan-07'  # images older than this date discarded\
cutoff_nadir = 30 # Images at nadir angles greater than threshold discarded
cutoff_pan_res = 1 # Images below this resolution discarded
accepted_bands = ['PAN_MS1','PAN_MS1_MS2'] #  Images with any other band entry discarded

# Categorical Search: remove disqualified images. Copy of dataframe taken, renamed to 'out_1stcut'.
out_1stcut = out.loc[(out['CloudCover'] <= cutoff_cloud_cover) & 
                     (out['Overlap_%'] >= cutoff_overlap) & 
                     (out['TS'] > pd.Timestamp(cutoff_date_lower, tz = 0)) & 
                     (out['TS'] < pd.Timestamp(cutoff_date_upper, tz = 0)) &
                     (out['ImageBands'].isin(accepted_bands)) & 
                     (out['OffNadirAngle'] <= cutoff_nadir) & 
                     (out['PanResolution'] <= cutoff_pan_res)
                    ]

# Print to consol remaining images after categorical search undertaken
print '\nNumber of results remaining: %s' % len(out_1stcut.index)
# Out:
# Number of results remaining: 131

# %% [markdown]
# ### Apply Image Quality Ranking
# For the remaining images that met minimum quality thresholds, rank them, best to worst. This is done on a points-based system. Images accrue points for:
# - every % of cloud cover (1 point)
# - every % of missed overlap with the AOI (1 point)
# - every week away from the optimal date (1 point)
# - every degree away from nadir (1 point)
# - every cm of resolution worse than the optimal resolution
#
# User preferences are defined in the 'pref_weights' dictionary.
# Ensure all weights sum to 1.

# %%
# Define continuous image ranking preferences
optimal_date =  '1-Jan-19' # Optimal date (enter as dd-mmm-yy)
optimal_pan_res = 0.4 # Optimal pan resolution, metres
optimal_nadir = 0 # optimal image angle. 0 = vertical

# Define continuous image ranking preference weights. Must sum to 1.
# If user cares more about scenes being contemporaneous, up 'date' weighting at expense of other categories. 
pref_weights = {
    'cloud_cover': 0.5,
    'overlap':0.5,
    'date': 0.0,
    'nadir': 0.0,
    'resolution': 0.0
    }

# Apply ranking method over all non-disqualified search results for each field
optimal_date = pd.to_datetime(optimal_date, utc = True)

# each 1% of cloud cover = 1 point
out_1stcut['points_CC'] = (out_1stcut['CloudCover'])  

# each 1% of overlap missed = 1 point
out_1stcut['points_Overlap'] = (100 - out_1stcut['Overlap_%'])  

# each week away from the optimal date = 1 point 
out_1stcut['points_Date'] = ((abs(out_1stcut['TS'] - optimal_date)).view('int64') / 60 / 60 / 24 / 1E9) / 7 

# each degree off nadir = 1 point
out_1stcut['points_Nadir'] = abs(out_1stcut['OffNadirAngle'] - optimal_nadir) 

# each cm of resolution worse than the optimal resolution = 1 point
out_1stcut['points_Res'] = (out_1stcut['PanResolution'] - optimal_pan_res).apply(lambda x: max(x,0)) * 100 

# Define ranking algorithm - weight point components defined above by the preference weighting dictionary
def Ranker(out_1stcut, pref_weights):
    a = out_1stcut['points_CC'] * pref_weights['cloud_cover']
    b = out_1stcut['points_Overlap'] * pref_weights['overlap']
    c = out_1stcut['points_Date'] * pref_weights['date'] 
    d = out_1stcut['points_Nadir'] * pref_weights['nadir']
    e = out_1stcut['points_Res'] * pref_weights['resolution']
    
    # Score is linear addition of the number of 'points' the scene wins as defined above. More points = worse fit to criteria
    rank = a + b + c + d + e
    return rank

# Add new column - Rank Result - with the total number of points accrued by the scene 
out_1stcut['RankResult'] = Ranker(out_1stcut,pref_weights)

# Add a Preference order column - Pref_Order - based on Rank Result, sorted ascending (best scene first)
out_1stcut = out_1stcut.sort_values(by = 'RankResult', axis = 0, ascending = True)
out_1stcut = out_1stcut.reset_index()
out_1stcut['Pref_order'] = out_1stcut.index + 1
out_1stcut = out_1stcut.drop(['index'], axis = 1)

# %% [markdown]
# ### Output image results .csv
# Before construction of the scene mosaic, output a .csv with the details of selected and ranked scenes, named 'Scene_List.csv'

# %%
cols = ['ID','Sensor','ImageBands','Date','Time','CloudCover','Overlap_%','PanResolution','MultiResolution','OffNadirAngle','On_IDAHO','Pref_order','RankResult','points_CC','points_Overlap','points_Date','points_Nadir','points_Res','browseURL','Full_scene_WKT','useful_area_WKT','missing_area_WKT']
out_1stcut = out_1stcut[cols]
out_1stcut['AOI_WKT'] = AOI
out_1stcut.to_csv(os.path.join('C:\Users\charl\Documents\GOST\GBDX\Padma','Scene_List.csv'))

# %% [markdown]
# ### Build composite shape from useful area WKT
#
# This block takes the AOI and subtracts from it, in rank-preferred order, the useable scene area for each catalog ID. This results in a diminishing 'AOI remaining' area, which the loop seeks to fill, with ever decreasing 'utility' images. A new column in the dataframe is created - 'used_area_wkt' - which is the geometry of the image which should be requested if trying to make a mosaic of these catalog IDs.

# %%
# Create a new copy of the dataframe to work on
finaldf = out_1stcut

# Add column for used scene region area, expressed as .wkt
finaldf['used_scene_region_WKT'] = 0
finaldf['used_area'] = 0

# Set initial value of AOI_remaining to the full AOI under consideration
AOI_remaining = AOI

# Create two lists - usedareas for the areas of scenes used in the final product, and AOI_rems to record sequential reduction in 
# remaining AOI that needs to be filled
usedareas = []
AOI_rems = []

# Set up loop for each image in dataframe of ranked images
for s in finaldf.index:
    print 'calculating for %s' % s
    
    # pick up the WKT of the useful area as the useful_scene_region variable
    useful_scene_region = finaldf['useful_area_WKT'].loc[s]
    
    # Set up try loop - to catch if there is no intersection of AOI_remaining and useful_scene_region
    try: 
        
        # define 'used_scene_region' as the useable bit of the image that overlaps the AOI
        used_scene_region = AOI_remaining.intersection(useful_scene_region)
        
        # calculate the area of that region
        used_area = used_scene_region.area
        
        # Check to see if this is a geometry collection. This shapely type if for 'jumbles' of outputs (e.g. Polygons + Lines)
        # This can be created if the intersection process decides that it also wants a 1-pixel strip from the bottom of the image
        # as well as the main chunk. This won't translate back to a shapefile, so we drop non-Polygon objects iteratively. 
        if used_scene_region.type == 'GeometryCollection':
            xlist = []
            
            # Iterate through all objects in the geometry collection
            for y in used_scene_region.geoms:
                
                # Add polygons to a fresh list
                if y.type == 'Polygon':
                    xlist.append(y)
                    
            # Convert that list to a multipolygon object
            used_scene_region = MultiPolygon(xlist)
        else:
            pass
        
        # Append the used bit of the image to the usedareas list. 
        usedareas.append(used_scene_region)
        
        # Add two new columns to the dataframe - the used scene geometry in wkt, and the area of the used scene
        finaldf['used_scene_region_WKT'].loc[s] = used_scene_region
        finaldf['used_area'].loc[s] = used_area
        
        # Redefine the area of the AOI that needs to be filled by the next, lower-rank image
        AOI_remaining = AOI_remaining.difference(used_scene_region)
        
        # Add this to the AOI_rems list for troubelshooting and verification
        AOI_rems.append(AOI_remaining)
    except:
        pass
# Out:
# calculating for 0
# calculating for 1
# calculating for 2
# calculating for 3
# calculating for 4
# calculating for 5
# calculating for 6

# %% [markdown]
# ### Output and Summary
# End of the process - print how much of the AOI was eventually covered with these settings, and send the .csv to file as 'Final_Scene_List'

# %%
# Drop from the scene list any scene where the area used is less than 1% of the AOI
finaldf = finaldf.loc[finaldf['used_area'] > (AOI.area / 100)]

# Print summary statistics to consol
print 'Remaining images: %s' % len(finaldf.index)
print 'Proportion of AOI covered: %d percent' % (finaldf['used_area'].sum() / AOI.area * 100)
print 'Remaining area:'
AOI_remaining

# Send final .csv to file
finaldf.to_csv('Final_Scene_List_Konna.csv')
# Out:
# Remaining images: 2
# Proportion of AOI covered: 100 percent
# Remaining area:

# %%
o = out_1stcut.copy()
o = o.sort_values(by = 'Overlap_%', ascending = False)[:20]

# %%
order_list = list(o.ID)

order_receipts = []
print 'Number of images to be ordered: %d' % len(order_list)

consent = 'I agree to ordering these image IDs to IDAHO'

if consent == 'I agree to ordering these image IDs to IDAHO':
    for x in order_list:
        try:
            order_id = gbdx.ordering.order(x)
            order_receipts.append(order_id)
        except:
            order_receipts.append('error!')
else: 
    print 'please write out your consent in the consent variable above'
# Out:
# Number of images to be ordered: 20

# %%
for receipt in order_receipts[:20]:
    try:
        print(gbdx.ordering.status(receipt))
    except:
        print('error!')
# Out:
# [{u'acquisition_id': u'103001001F9E0000', u'state': u'delivered', u'location': u's3://receiving-dgcs-tdgplatform-com/059092634010_01_003'}]
# [{u'acquisition_id': u'1030010064CCE300', u'state': u'delivered', u'location': u's3://receiving-dgcs-tdgplatform-com/058881809010_01_003'}]
# [{u'acquisition_id': u'1030010077677700', u'state': u'delivered', u'location': u's3://receiving-dgcs-tdgplatform-com/058385670010_01_003'}]
# error!
# [{u'acquisition_id': u'1030010063CEDE00', u'state': u'delivered', u'location': u's3://receiving-dgcs-tdgplatform-com/059092635010_01_003'}]
# error!
# [{u'acquisition_id': u'1030010003D0A300', u'state': u'delivered', u'location': u's3://receiving-dgcs-tdgplatform-com/059092636010_01_003'}]
# [{u'acquisition_id': u'1050410004BE5400', u'state': u'delivered', u'location': u's3://receiving-dgcs-tdgplatform-com/059092637010_01_003'}]
# [{u'acquisition_id': u'105041000F7ACA00', u'state': u'delivered', u'location': u's3://receiving-dgcs-tdgplatform-com/059092638010_01_003'}]
# [{u'acquisition_id': u'10504100005EE300', u'state': u'delivered', u'location': u's3://receiving-dgcs-tdgplatform-com/059092639010_01_003'}]
# [{u'acquisition_id': u'10500100078B6600', u'state': u'delivered', u'location': u's3://receiving-dgcs-tdgplatform-com/059092641010_01_003'}]
# [{u'acquisition_id': u'1040010045AEE400', u'state': u'delivered', u'location': u's3://receiving-dgcs-tdgplatform-com/059092642010_01_003'}]
# error!
# [{u'acquisition_id': u'1050410001313700', u'state': u'delivered', u'location': u's3://receiving-dgcs-tdgplatform-com/059092643010_01_003'}]
# [{u'acquisition_id': u'105041000F7ACB00', u'state': u'delivered', u'location': u's3://receiving-dgcs-tdgplatform-com/059092644010_01_003'}]
# [{u'acquisition_id': u'1050410004BC4000', u'state': u'delivered', u'location': u's3://receiving-dgcs-tdgplatform-com/059092645010_01_003'}]
# [{u'acquisition_id': u'1050410001EC1E00', u'state': u'delivered', u'location': u's3://receiving-dgcs-tdgplatform-com/059092646010_01_003'}]
# [{u'acquisition_id': u'1030010054688100', u'state': u'delivered', u'location': u's3://receiving-dgcs-tdgplatform-com/059092647010_01_003'}]
# [{u'acquisition_id': u'1050410012640600', u'state': u'delivered', u'location': u's3://receiving-dgcs-tdgplatform-com/059092648010_01_003'}]
# [{u'acquisition_id': u'1030010011388F00', u'state': u'delivered', u'location': u's3://receiving-dgcs-tdgplatform-com/059092649010_01_003'}]

# %%
import sys, os
sys.path.insert(0, r"C:\Users\charl\Documents\GitHub\GOST_GBDX")
from GOST_GBDx_Tools import gbdxTasks
from GOST_GBDx_Tools import gbdxURL_misc
from gbdxtools import CatalogImage

curTasks = gbdxTasks.GOSTTasks(gbdx)
gbdxUrl = gbdxURL_misc.gbdxURL(gbdx)

curFolder=r'C:\Users\charl\Documents\GOST\GBDX\Padma'

# %%
for root, dirs, files in os.walk(curFolder, topdown=False):
    pass

i = 0
output = o
for i in range(0, len(output)):
    
        cWKT = output.AOI_WKT.iloc[i]
        catID = output.ID.iloc[i]
        curFile = 'img_%s.tif' % (catID)
         
        a = os.path.join(curFolder, curFile)

        if curFile in files:
            print('file already exists, skipping download: %s' % curFile)
            pass
        else:
            print('downloading: %s' % curFile)
            curTasks.downloadImage(catID, a, boundingBox=cWKT.bounds, imgChipSize = 100000)
# Out:
# downloading: img_103001001F9E0000.tif
# ---------------------------------------------------------------------------
# CPLE_FileIO                               Traceback (most recent call last)
# <ipython-input-47-ee4c0f29578f> in <module>()
#      17         else:
#      18             print('downloading: %s' % curFile)
# ---> 19             curTasks.downloadImage(catID, a, boundingBox=cWKT.bounds, imgChipSize = 100000)
#
# C:\Users\charl\Documents\GitHub\GOST_GBDX\GOST_GBDx_Tools\gbdxTasks.pyc in downloadImage(self, cat_id, outFile, output, boundingBox, curWKT, imgChipSize, band_type, panSharpen, acomp, getOutSize)
#      83                             outImage = self.calculateIndices(curChip, sensor, outputChip)
#      84         else:
# ---> 85             img.geotiff(path=outFile)
#      86         return 1
#      87
#
# C:\Users\charl\AppData\Local\Continuum\anaconda3\envs\GGCW\lib\site-packages\gbdxtools\images\meta.pyc in geotiff(self, **kwargs)
#     313         if 'proj' not in kwargs:
#     314             kwargs['proj'] = self.proj
# --> 315         return to_geotiff(self, **kwargs)
#     316
#     317     def preview(self, **kwargs):
#
# C:\Users\charl\AppData\Local\Continuum\anaconda3\envs\GGCW\lib\site-packages\gbdxtools\ipe\io.pyc in to_geotiff(arr, path, proj, bands, **kwargs)
#      59         meta.update(blockxsize=x_size, blockysize=y_size, tiled="yes")
#      60
# ---> 61     with rasterio.open(path, "w", **meta) as dst:
#      62         writer = rio_writer(dst)
#      63         result = store(arr, writer, compute=False)
#
# C:\Users\charl\AppData\Local\Continuum\anaconda3\envs\GGCW\lib\site-packages\rasterio\__init__.pyc in open(path, mode, driver, width, height, count, crs, transform, dtype, nodata, **kwargs)
#     191         raise ValueError(
#     192             "mode string must be one of 'r', 'r+', or 'w', not %s" % mode)
# --> 193     s.start()
#     194     return s
#     195
#
# rasterio/_io.pyx in rasterio._io.RasterUpdater.start (rasterio/_io.c:20189)()
#
# rasterio/_io.pyx in rasterio._io.RasterUpdater.start (rasterio/_io.c:20066)()
#
# rasterio/_io.pyx in rasterio._io.RasterUpdater.start (rasterio/_io.c:20015)()
#
# rasterio/_err.pyx in rasterio._err.CPLErrors.check (rasterio/_err.c:1773)()
#
# CPLE_FileIO: Free disk space available is 16373051392 bytes, whereas 180824557440 are at least necessary. You can disable this check by defining the CHECK_DISK_FREE_SPACE configuration option to FALSE.

# %%
t = list(o.ID.sort_values(ascending = False))[3:]

# %%
print(t)
# Out:
# [u'1050410012640600', u'105041000F7ACB00', u'105041000F7ACA00', u'1050410004BE5400', u'1050410004BC4000', u'1050410001EC1E00', u'1050410001313700', u'10504100005EE300', u'10500100078B6600', u'1040010045AEE400', u'1030010077677700', u'1030010064CCE300', u'1030010063CEDE00', u'1030010054688100', u'103001001F9E0000', u'1030010011388F00', u'1030010003D0A300']

# %%
k = '1050410012640600,
105041000F7ACB00, 105041000F7ACA00, 1050410004BE5400, 1050410004BC4000, 1050410001EC1E00, 1050410001313700, 10504100005EE300, 10500100078B6600, 1040010045AEE400, 1030010077677700, 1030010064CCE300, 1030010063CEDE00, 1030010054688100, 103001001F9E0000, 1030010011388F00, 1030010003D0A300'
