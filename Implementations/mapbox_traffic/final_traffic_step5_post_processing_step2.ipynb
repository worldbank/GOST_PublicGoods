# %% [markdown]
# # Step5: Post-Processing function step 2

# %%
import os, sys, time, importlib
import osmnx

import geopandas as gpd
import pandas as pd
import networkx as nx
import numpy as np
sys.path.append("../../../GOSTnets")
import GOSTnets as gn

# pip install osmium
# import osmium, logging
# import shapely.wkb as wkblib

from shapely.geometry import LineString, Point

# %%
# This is a Jupyter Notebook extension which reloads all of the modules whenever you run the code
# This is optional but good if you are modifying and testing source code
# %load_ext autoreload
# %autoreload 2

# %%
from GOSTnets.load_traffic2 import *

# %%
# read graph
G = nx.read_gpickle('./sri_lanka_unclean2_w_time_largest_20200616.pickle')

# %%
len(G.edges)
# Out:
# 1675316

# %%
# import shapefile as GPD
study_area = gpd.read_file("./output_edges_shapefiles_merged_20200616/all_weighted_sec_saved_edges_merged.shp")

# %%
study_area
# Out:
#                 o           d  w  sec_saved  mean_speed  edge_lengt  \
# 0        50366374  3505017714  1   0.000000   33.994048   48.379031
# 1        50366379  3783146983  1   0.000000   30.216766   87.889220
# 2        50366398  5339962994  1   0.000000   58.969246   66.762605
# 3        50366405  4505507529  1   0.000000   50.306052   20.626614
# 4        50366409  4505485105  1   0.000000   35.605655  142.233525
# ...           ...         ... ..        ...         ...         ...
# 77942   849245097  5566426659  2   9.013771         NaN   33.587352
# 77943  1971685346  4045357654  1  13.625541         NaN   46.282342
# 77944  2908413770  5558608300  1   0.995321         NaN    4.641715
# 77945  5261458386  5566426654  2  12.291682         NaN   14.146847
# 77946   849238506   847439889  2   7.855553         NaN   38.223685
#
#       edge_infra  weighted_s  length infra_type  max_speed  min_speed   mode  \
# 0          trunk    0.000000     NaN       None        NaN        NaN   None
# 1          trunk    0.000000     NaN       None        NaN        NaN   None
# 2          trunk    0.000000     NaN       None        NaN        NaN   None
# 3          trunk    0.000000     NaN       None        NaN        NaN   None
# 4          trunk    0.000000     NaN       None        NaN        NaN   None
# ...          ...         ...     ...        ...        ...        ...    ...
# 77942   tertiary   18.027542     NaN       None       26.0       26.0  drive
# 77943  secondary   13.625541     NaN       None       39.0       39.0  drive
# 77944  secondary    0.995321     NaN       None       33.0       33.0  drive
# 77945   tertiary   24.583364     NaN       None       19.0       19.0  drive
# 77946  secondary   15.711106     NaN       None       25.0       25.0  drive
#
#             osm_id  speed      time     imp_cost  \
# 0              NaN    NaN       NaN          NaN
# 1              NaN    NaN       NaN          NaN
# 2              NaN    NaN       NaN          NaN
# 3              NaN    NaN       NaN          NaN
# 4              NaN    NaN       NaN          NaN
# ...            ...    ...       ...          ...
# 77942   71184828.0   26.0  4.650556  6274.117437
# 77943  161273928.0   39.0  4.272216          NaN
# 77944   71184920.0   33.0  0.506369          NaN
# 77945   71184828.0   19.0  2.680455  2642.631033
# 77946   71371146.0   25.0  5.504211          NaN
#
#                                                 geometry
# 0        LINESTRING (80.10994 7.15558, 80.11037 7.15554)
# 1        LINESTRING (80.10258 7.15177, 80.10324 7.15222)
# 2        LINESTRING (80.08677 7.13455, 80.08734 7.13474)
# 3        LINESTRING (80.08006 7.13353, 80.08023 7.13360)
# 4        LINESTRING (80.09700 7.14654, 80.09792 7.14744)
# ...                                                  ...
# 77942  MULTILINESTRING ((80.02252 9.66229, 80.02277 9...
# 77943  MULTILINESTRING ((80.15228 8.77194, 80.15255 8...
# 77944  MULTILINESTRING ((80.02139 9.68385, 80.02135 9...
# 77945  MULTILINESTRING ((80.02386 9.66143, 80.02397 9...
# 77946  MULTILINESTRING ((80.03533 9.67379, 80.03499 9...
#
# [77947 rows x 18 columns]

# %%
study_area.sort_values(by=['weighted_s'], ascending=False)
# Out:
#                 o           d   w    sec_saved  mean_speed  edge_lengt  \
# 77728  3324754806   568948837  20  1812.698863         NaN   34.633360
# 54742  4366114665  1242791243  26   423.745511   10.000000         NaN
# 77680   568948837   568948805  19   560.757967         NaN   34.716249
# 48530  1172970454  1240466608  20   532.068062   20.000000         NaN
# 77670   258049598  3756747936  20   348.734282         NaN   25.583520
# ...           ...         ...  ..          ...         ...         ...
# 44312  1924916097  1924916048  18  -182.105634   71.592262  465.893149
# 44287  1924916043  1924916097  18  -183.605537   71.592262  469.730454
# 45701  3324754796  3324754703  20  -188.701616   69.128968  473.567244
# 45616  3324754683  3324754742  20  -209.651849   69.128968  526.144136
# 47666  5212865163  5212865156  18  -241.800812   77.709821  523.232772
#
#       edge_infra    weighted_s      length infra_type  max_speed  min_speed  \
# 77728  secondary  36253.977256         NaN       None       62.0       23.0
# 54742       None  11017.383291   60.362608   tertiary        NaN        NaN
# 77680  secondary  10654.401370         NaN       None       36.0       36.0
# 48530       None  10641.361250  246.327807  secondary        NaN        NaN
# 77670  secondary   6974.685650         NaN       None       35.0       33.0
# ...          ...           ...         ...        ...        ...        ...
# 44312  secondary  -3277.901405         NaN       None        NaN        NaN
# 44287  secondary  -3304.899671         NaN       None        NaN        NaN
# 45701  secondary  -3774.032312         NaN       None        NaN        NaN
# 45616  secondary  -4193.036986         NaN       None        NaN        NaN
# 47666  secondary  -4352.414621         NaN       None        NaN        NaN
#
#         mode       osm_id      speed      time  imp_cost  \
# 77728  drive  325856824.0  35.370536  3.524970       NaN
# 54742   None          NaN        NaN       NaN       NaN
# 77680  drive  325857446.0  36.000000  3.471625       NaN
# 48530   None          NaN        NaN       NaN       NaN
# 77670  drive  507709803.0  34.975198  2.633314       NaN
# ...      ...          ...        ...       ...       ...
# 44312   None          NaN        NaN       NaN       NaN
# 44287   None          NaN        NaN       NaN       NaN
# 45701   None          NaN        NaN       NaN       NaN
# 45616   None          NaN        NaN       NaN       NaN
# 47666   None          NaN        NaN       NaN       NaN
#
#                                                 geometry
# 77728  MULTILINESTRING ((80.74927 7.69960, 80.74902 7...
# 54742    LINESTRING (81.23471 8.57738, 81.23462 8.57684)
# 77680  MULTILINESTRING ((80.77178 7.70753, 80.77148 7...
# 48530    LINESTRING (81.22839 8.58093, 81.23036 8.57988)
# 77670  MULTILINESTRING ((80.65386 7.70718, 80.65363 7...
# ...                                                  ...
# 44312    LINESTRING (80.90516 7.94905, 80.90920 7.95031)
# 44287    LINESTRING (80.90109 7.94782, 80.90516 7.94905)
# 45701    LINESTRING (80.72963 7.71306, 80.72858 7.71721)
# 45616    LINESTRING (80.71991 7.71845, 80.71652 7.71510)
# 47666    LINESTRING (80.87565 7.93638, 80.87983 7.93861)
#
# [77947 rows x 18 columns]
